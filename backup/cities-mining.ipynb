# %% [markdown]
# # Global Financial Centers Data Mining

# %%
import pandas as pd
import numpy as np

import re

import json
import requests
from urllib.parse import quote_plus

import matplotlib.pyplot as plt
import geopandas as gpd
import geoplot as gplt
from geojson import Feature, FeatureCollection, dump
import folium
from shapely.geometry import box, mapping, polygon, multipolygon
from foursquare import generate_square_grid, plot_foursquare_search_grid

# %%
# Request list of Global Financial Centers and their Global Financial Centres Index (GFCI) from Wikipedia

wiki_url = "https://en.wikipedia.org/wiki/Global_Financial_Centres_Index"

html_content=requests.get(wiki_url).content

# Find two-column dataframe and drop unneeded columns
df = pd.read_html(html_content)[1].append(pd.read_html(html_content)[2])
df.drop(columns=['Rank', 'Change', 'Change.1'], inplace=True)

# Exclude city names' parenthetical notes
df.Centre = df.Centre.str.replace(' \(BOT\)', "").values
df.Centre = df.Centre.str.replace(' \(CD\)', "").values
df.head()
# Out:
#           Centre  Rating
# 0  New York City     790
# 1         London     773
# 2      Hong Kong     771
# 3      Singapore     762
# 4       Shanghai     761

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 51
# Data columns (total 2 columns):
# Centre    104 non-null object
# Rating    104 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
# df.to_csv('data/cities_ratings.csv')

df = pd.read_csv('data/cities_ratings.csv', index_col=0)
df.head()
# Out:
#           Centre  Rating
# 0  New York City     790
# 1         London     773
# 2      Hong Kong     771
# 3      Singapore     762
# 4       Shanghai     761

# %%
non_financial_cities = "https://en.wikipedia.org/wiki/List_of_largest_cities"

non_financial_html=requests.get(non_financial_cities).content
df_non_financial = pd.read_html(non_financial_html)[1]
df_non_financial
# Out:
#              City        Country Skyline                 City proper  \
#              City        Country Skyline                  Definition
# 0           Tokyo          Japan     NaN       Metropolis prefecture
# 1         Jakarta      Indonesia     NaN      Special capital region
# 2       Chongqing          China     NaN                Municipality
# 3          Manila    Philippines     NaN                        City
# 4           Delhi          India     NaN  National capital territory
# ..            ...            ...     ...                         ...
# 73     Düsseldorf        Germany     NaN              Urban district
# 74         Madrid          Spain     NaN                Municipality
# 75        Toronto         Canada     NaN                        City
# 76          Surat          India     NaN                Municipality
# 77  San Francisco  United States     NaN    Consolidated city-county
#
#                               Metropolitan area             Urban area[9]  \
#         Population  Area(km2)        Population   Area(km2)    Population
# 0   13,515,271[10]  2,191[10]    37,274,000[11]  13,452[11]      38505000
# 1   10,154,134[12]    664[12]    33,430,285[13]   7,063[13]      34365000
# 2   30,752,000[14]      82403               NaN         NaN       8300000
# 3    1,780,148[15]         43    12,877,253[15]         620      29700000
# 4   16,753,235[16]       1484    29,000,000[17]   3,483[17]      28125000
# ..             ...        ...               ...         ...           ...
# 73     642,304[86]        217     1,555,985[48]         NaN       6660000
# 74   3,266,126[87]        606     6,641,649[48]         NaN       6345000
# 75   2,503,281[88]    630[88]     5,928,040[89]   5,906[89]       6630000
# 76   4,466,826[90]    327[90]               NaN         NaN       6385000
# 77     883,305[25]        122     4,729,484[91]   6,417[91]       6100000
#
#
#    Area(km2)
# 0   8,223[a]
# 1       3367
# 2   1,489[b]
# 3   1,813[c]
# 4       2240
# ..       ...
# 73  2,655[m]
# 74      1360
# 75      2300
# 76       233
# 77  2,865[n]
#
# [78 rows x 10 columns]

# %%
non_financial_cities = [value for value in df_non_financial['City']['City'] if value not in list(df.Centre)] 
non_financial_cities
# Out:
# ['Chongqing',
#  'Delhi',
#  'Lagos',
#  'Dhaka',
#  'Cairo',
#  'Karachi',
#  'Kolkata',
#  'Tehran',
#  'Kinshasa',
#  'Baoding',
#  'Lahore',
#  'Lima',
#  'Bangalore',
#  'Ho Chi Minh City',
#  'Harbin',
#  'Wuhan',
#  'Shijiazhuang',
#  'Bogotá',
#  'Suzhou',
#  'Linyi',
#  'Chennai',
#  'Nagoya',
#  'Nanyang',
#  'Zhengzhou',
#  'Hyderabad',
#  'Surabaya',
#  "Xi'an",
#  'Quanzhou',
#  'Dongguan',
#  'Bandung',
#  'Hanoi',
#  'Shenyang',
#  'Baghdad',
#  'Onitsha',
#  'Ahmedabad',
#  'Luanda',
#  'Dallas',
#  'Pune',
#  'Houston',
#  'Düsseldorf',
#  'Surat']

# %%
# drop Delhi since exists in top centres list as New Delhi
del non_financial_cities[1]
non_financial_cities
# Out:
# ['Chongqing',
#  'Lagos',
#  'Dhaka',
#  'Cairo',
#  'Karachi',
#  'Kolkata',
#  'Tehran',
#  'Kinshasa',
#  'Baoding',
#  'Lahore',
#  'Lima',
#  'Bangalore',
#  'Ho Chi Minh City',
#  'Harbin',
#  'Wuhan',
#  'Shijiazhuang',
#  'Bogotá',
#  'Suzhou',
#  'Linyi',
#  'Chennai',
#  'Nagoya',
#  'Nanyang',
#  'Zhengzhou',
#  'Hyderabad',
#  'Surabaya',
#  "Xi'an",
#  'Quanzhou',
#  'Dongguan',
#  'Bandung',
#  'Hanoi',
#  'Shenyang',
#  'Baghdad',
#  'Onitsha',
#  'Ahmedabad',
#  'Luanda',
#  'Dallas',
#  'Pune',
#  'Houston',
#  'Düsseldorf',
#  'Surat']

# %%
len(non_financial_cities)
# Out:
# 40

# %%
# More populous cities hand-selected from to introduce a wide variety of non-financial cities
# They represent a mix of capitals and non-capitals 

africa_balancer = [
    'Ouagadougou',
    'Abidjan',
    'Addis Ababa',
    'Kumasi',
    'Conakry',
    'Nairobi',
    'Antananarivo',
    'Fès',
    'Maputo',
    'Niamey',
    'Dakar',
    'Freetown',
    'Mogadishu',
    'Kampala',
    'Dar es Salaam',
    'Lusaka',
    'Harare'
]

americas_balancer = [
    'Calgary',
    'Montréal',
    'Havana',
    'Santo Domingo',
    'Tegucigalpa',
    'Guadalajara',
    'Juárez',
    'La Laguna',
    'León',
    'Monterrey',
    'Puebla-Tlaxcala',
    'Querétaro',
    'San Luis Potosí-Soledad de Graciano Sánchez',
    'Tijuana',
    'Toluca',
    'Philadelphia',
    'Phoenix',
    'San Antonio',
    'San Diego',
    'Córdoba',
    'Mendoza',
    'Rosario',
    'Santa Cruz',
    'Belém',
    'Belo Horizonte',
    'Campinas',
    'Fortaleza',
    'Guarulhos',
    'Manaus',
    'Salvador',
    'Barranquilla',
    'Cali',
    'Cartagena',
    'Medellín',
    'Esmeraldas',
    'QUITO',
    'Montevideo',
    'Caracas',
    'Maracaibo'
]

asia_balancer = [
    'Kabul Center',
    'Yerevan',
    'Baku',
    'Chittagong',
    'Phnom Penh',
    'Bat Dambang',
    'Tbilisi',
    'Agra',
    'Amritsar',
    'Aurangabad',
    'Bhopal',
    'Dhanbad',
    'Indore',
    'Kalyan Dombivali',
    'Kanpur',
    'Calcutta',
    'Lucknow',
    'Ludhiana',
    'Meerut',
    'Nagpur',
    'Nashik',
    'Patna',
    'Pimpri Chinchwad',
    'Rajkot',
    'Srinagar',
    'Thane',
    'Vadodara',
    'Vasai-Virar City',
    'Batam',
    'Bogor',
    'Makasar',
    'Medan',
    'Surabaya',
    'Tangerang',
    'Ahwaz',
    'Esfahan',
    'Karaj',
    'Mashhad',
    'Qom',
    'Tabriz',
    'Al-Basrah Qadha Center',
    'Al-Mosal Qadha Center',
    'Jerusalem',
    'Fukuoka',
    'Kobe',
    'Kawasaki',
    'Kyoto',
    'Sapporo',
    'Yokohama',
    'Amman',
    'Astana',
    'Ulannbaatar',
    'Mandalay',
    'Yangon',
    'Kathmandu',
    'Caloocan',
    'Davao',
    'Quezon City',
    'Busan',
    'Daegu',
    'Incheon',
    'Ulsan',
    'Jiddah',
    'Makkah',
    'Aleppo',
    'Hama',
    'Homs',
    'Idleb',
    'Chon Buri',
    'Samut Prakan',
    'Adana',
    'Antalya',
    'Balıkesir',
    'Bursa',
    'Diyarbakir',
    'Izmir',
    'Gaziantep',
    'Hatay',
    'Kocaeli',
    'Konya',
    'Manisa',
    'Mersin',
    'Sanliurfa',
    'Tashkent',
    "Sana'a"
]

europe_balancer = [
    'Wien',
    'Minsk',
    'Zagreb',
    'Praha',
    'Lille',
    'Marseille',
    'München',
    'Bucharest',
    'Ekaterinburg',
    'Kazan',
    'Nizhny Novgorod',
    'Novosibirsk',
    'Omsk',
    'Ufa',
    'Belgrade',
    'Barcelona',
    'Kharkiv',
    'Birmingham',
]

oceania_balancer = [
    'Adelaide',
    'Brisbaine',
    'Perth',
    'Auckland'
]

balancers = africa_balancer + americas_balancer + asia_balancer + europe_balancer + oceania_balancer
balancers
# Out:
# ['Ouagadougou',
#  'Abidjan',
#  'Addis Ababa',
#  'Kumasi',
#  'Conakry',
#  'Nairobi',
#  'Antananarivo',
#  'Fès',
#  'Maputo',
#  'Niamey',
#  'Dakar',
#  'Freetown',
#  'Mogadishu',
#  'Kampala',
#  'Dar es Salaam',
#  'Lusaka',
#  'Harare',
#  'Calgary',
#  'Montréal',
#  'Havana',
#  'Santo Domingo',
#  'Tegucigalpa',
#  'Guadalajara',
#  'Juárez',
#  'La Laguna',
#  'León',
#  'Monterrey',
#  'Puebla-Tlaxcala',
#  'Querétaro',
#  'San Luis Potosí-Soledad de Graciano Sánchez',
#  'Tijuana',
#  'Toluca',
#  'Philadelphia',
#  'Phoenix',
#  'San Antonio',
#  'San Diego',
#  'Córdoba',
#  'Mendoza',
#  'Rosario',
#  'Santa Cruz',
#  'Belém',
#  'Belo Horizonte',
#  'Campinas',
#  'Fortaleza',
#  'Guarulhos',
#  'Manaus',
#  'Salvador',
#  'Barranquilla',
#  'Cali',
#  'Cartagena',
#  'Medellín',
#  'Esmeraldas',
#  'QUITO',
#  'Montevideo',
#  'Caracas',
#  'Maracaibo',
#  'Kabul Center',
#  'Yerevan',
#  'Baku',
#  'Chittagong',
#  'Phnom Penh',
#  'Bat Dambang',
#  'Tbilisi',
#  'Agra',
#  'Amritsar',
#  'Aurangabad',
#  'Bhopal',
#  'Dhanbad',
#  'Indore',
#  'Kalyan Dombivali',
#  'Kanpur',
#  'Calcutta',
#  'Lucknow',
#  'Ludhiana',
#  'Meerut',
#  'Nagpur',
#  'Nashik',
#  'Patna',
#  'Pimpri Chinchwad',
#  'Rajkot',
#  'Srinagar',
#  'Thane',
#  'Vadodara',
#  'Vasai-Virar City',
#  'Batam',
#  'Bogor',
#  'Makasar',
#  'Medan',
#  'Surabaya',
#  'Tangerang',
#  'Ahwaz',
#  'Esfahan',
#  'Karaj',
#  'Mashhad',
#  'Qom',
#  'Tabriz',
#  'Al-Basrah Qadha Center',
#  'Al-Mosal Qadha Center',
#  'Jerusalem',
#  'Fukuoka',
#  'Kobe',
#  'Kawasaki',
#  'Kyoto',
#  'Sapporo',
#  'Yokohama',
#  'Amman',
#  'Astana',
#  'Ulannbaatar',
#  'Mandalay',
#  'Yangon',
#  'Kathmandu',
#  'Caloocan',
#  'Davao',
#  'Quezon City',
#  'Busan',
#  'Daegu',
#  'Incheon',
#  'Ulsan',
#  'Jiddah',
#  'Makkah',
#  'Aleppo',
#  'Hama',
#  'Homs',
#  'Idleb',
#  'Chon Buri',
#  'Samut Prakan',
#  'Adana',
#  'Antalya',
#  'Balıkesir',
#  'Bursa',
#  'Diyarbakir',
#  'Izmir',
#  'Gaziantep',
#  'Hatay',
#  'Kocaeli',
#  'Konya',
#  'Manisa',
#  'Mersin',
#  'Sanliurfa',
#  'Tashkent',
#  "Sana'a",
#  'Wien',
#  'Minsk',
#  'Zagreb',
#  'Praha',
#  'Lille',
#  'Marseille',
#  'München',
#  'Bucharest',
#  'Ekaterinburg',
#  'Kazan',
#  'Nizhny Novgorod',
#  'Novosibirsk',
#  'Omsk',
#  'Ufa',
#  'Belgrade',
#  'Barcelona',
#  'Kharkiv',
#  'Birmingham',
#  'Adelaide',
#  'Brisbaine',
#  'Perth',
#  'Auckland']

# %%
non_financial_cities += balancers
non_financial_cities
# Out:
# ['Chongqing',
#  'Lagos',
#  'Dhaka',
#  'Cairo',
#  'Karachi',
#  'Kolkata',
#  'Tehran',
#  'Kinshasa',
#  'Baoding',
#  'Lahore',
#  'Lima',
#  'Bangalore',
#  'Ho Chi Minh City',
#  'Harbin',
#  'Wuhan',
#  'Shijiazhuang',
#  'Bogotá',
#  'Suzhou',
#  'Linyi',
#  'Chennai',
#  'Nagoya',
#  'Nanyang',
#  'Zhengzhou',
#  'Hyderabad',
#  'Surabaya',
#  "Xi'an",
#  'Quanzhou',
#  'Dongguan',
#  'Bandung',
#  'Hanoi',
#  'Shenyang',
#  'Baghdad',
#  'Onitsha',
#  'Ahmedabad',
#  'Luanda',
#  'Dallas',
#  'Pune',
#  'Houston',
#  'Düsseldorf',
#  'Surat',
#  'Ouagadougou',
#  'Abidjan',
#  'Addis Ababa',
#  'Kumasi',
#  'Conakry',
#  'Nairobi',
#  'Antananarivo',
#  'Fès',
#  'Maputo',
#  'Niamey',
#  'Dakar',
#  'Freetown',
#  'Mogadishu',
#  'Kampala',
#  'Dar es Salaam',
#  'Lusaka',
#  'Harare',
#  'Calgary',
#  'Montréal',
#  'Havana',
#  'Santo Domingo',
#  'Tegucigalpa',
#  'Guadalajara',
#  'Juárez',
#  'La Laguna',
#  'León',
#  'Monterrey',
#  'Puebla-Tlaxcala',
#  'Querétaro',
#  'San Luis Potosí-Soledad de Graciano Sánchez',
#  'Tijuana',
#  'Toluca',
#  'Philadelphia',
#  'Phoenix',
#  'San Antonio',
#  'San Diego',
#  'Córdoba',
#  'Mendoza',
#  'Rosario',
#  'Santa Cruz',
#  'Belém',
#  'Belo Horizonte',
#  'Campinas',
#  'Fortaleza',
#  'Guarulhos',
#  'Manaus',
#  'Salvador',
#  'Barranquilla',
#  'Cali',
#  'Cartagena',
#  'Medellín',
#  'Esmeraldas',
#  'QUITO',
#  'Montevideo',
#  'Caracas',
#  'Maracaibo',
#  'Kabul Center',
#  'Yerevan',
#  'Baku',
#  'Chittagong',
#  'Phnom Penh',
#  'Bat Dambang',
#  'Tbilisi',
#  'Agra',
#  'Amritsar',
#  'Aurangabad',
#  'Bhopal',
#  'Dhanbad',
#  'Indore',
#  'Kalyan Dombivali',
#  'Kanpur',
#  'Calcutta',
#  'Lucknow',
#  'Ludhiana',
#  'Meerut',
#  'Nagpur',
#  'Nashik',
#  'Patna',
#  'Pimpri Chinchwad',
#  'Rajkot',
#  'Srinagar',
#  'Thane',
#  'Vadodara',
#  'Vasai-Virar City',
#  'Batam',
#  'Bogor',
#  'Makasar',
#  'Medan',
#  'Surabaya',
#  'Tangerang',
#  'Ahwaz',
#  'Esfahan',
#  'Karaj',
#  'Mashhad',
#  'Qom',
#  'Tabriz',
#  'Al-Basrah Qadha Center',
#  'Al-Mosal Qadha Center',
#  'Jerusalem',
#  'Fukuoka',
#  'Kobe',
#  'Kawasaki',
#  'Kyoto',
#  'Sapporo',
#  'Yokohama',
#  'Amman',
#  'Astana',
#  'Ulannbaatar',
#  'Mandalay',
#  'Yangon',
#  'Kathmandu',
#  'Caloocan',
#  'Davao',
#  'Quezon City',
#  'Busan',
#  'Daegu',
#  'Incheon',
#  'Ulsan',
#  'Jiddah',
#  'Makkah',
#  'Aleppo',
#  'Hama',
#  'Homs',
#  'Idleb',
#  'Chon Buri',
#  'Samut Prakan',
#  'Adana',
#  'Antalya',
#  'Balıkesir',
#  'Bursa',
#  'Diyarbakir',
#  'Izmir',
#  'Gaziantep',
#  'Hatay',
#  'Kocaeli',
#  'Konya',
#  'Manisa',
#  'Mersin',
#  'Sanliurfa',
#  'Tashkent',
#  "Sana'a",
#  'Wien',
#  'Minsk',
#  'Zagreb',
#  'Praha',
#  'Lille',
#  'Marseille',
#  'München',
#  'Bucharest',
#  'Ekaterinburg',
#  'Kazan',
#  'Nizhny Novgorod',
#  'Novosibirsk',
#  'Omsk',
#  'Ufa',
#  'Belgrade',
#  'Barcelona',
#  'Kharkiv',
#  'Birmingham',
#  'Adelaide',
#  'Brisbaine',
#  'Perth',
#  'Auckland']

# %%
len(non_financial_cities)
# Out:
# 203

# %%
# pd.DataFrame(non_financial_cities).to_csv('data/cities_ratings_null.csv')

non_financial_cities = pd.read_csv('data/cities_ratings_null.csv', index_col=0)
non_financial_cities
# Out:
#               0
# 0     Chongqing
# 1         Lagos
# 2         Dhaka
# 3         Cairo
# 4       Karachi
# ..          ...
# 198  Birmingham
# 199    Adelaide
# 200   Brisbaine
# 201       Perth
# 202    Auckland
#
# [203 rows x 1 columns]

# %% [markdown]
# ### Add non-financial cities to ratings df without rating

# %%
# Combine rated cities with non-rated cities
df = df.append([{'Centre': c, 'Rating': np.NaN} for c in non_financial_cities.iloc[:,0]], ignore_index=True)

# Remove duplicates
df.drop(index=df[df.Centre.duplicated()].index, inplace=True)
df.reset_index(inplace=True, drop=True)
df
# Out:
#             Centre  Rating
# 0    New York City   790.0
# 1           London   773.0
# 2        Hong Kong   771.0
# 3        Singapore   762.0
# 4         Shanghai   761.0
# ..             ...     ...
# 297     Birmingham     NaN
# 298       Adelaide     NaN
# 299      Brisbaine     NaN
# 300          Perth     NaN
# 301       Auckland     NaN
#
# [302 rows x 2 columns]

# %%
# Prepare for merging with cities population
df['city'] = df.Centre.str.lower()
df
# Out:
#             Centre  Rating           city
# 0    New York City   790.0  new york city
# 1           London   773.0         london
# 2        Hong Kong   771.0      hong kong
# 3        Singapore   762.0      singapore
# 4         Shanghai   761.0       shanghai
# ..             ...     ...            ...
# 297     Birmingham     NaN     birmingham
# 298       Adelaide     NaN       adelaide
# 299      Brisbaine     NaN      brisbaine
# 300          Perth     NaN          perth
# 301       Auckland     NaN       auckland
#
# [302 rows x 3 columns]

# %%
cities_pop_regions = pd.read_csv('data/cities_pop_regions.csv', index_col=0)
cities_pop_regions
# Out:
#            city region country  population  \
# 0         tokyo     40      jp    31480498
# 1      shanghai     23      cn    14608512
# 2        bombay     16      in    12692717
# 3       karachi     05      pk    11627378
# 4         delhi     07      in    10928270
# ..          ...    ...     ...         ...
# 615     asansol     28      in      504320
# 616        arak     34      ir      503673
# 617   astrakhan     07      ru      502537
# 618      zhuhai     30      cn      501199
# 619  gold coast     04      au      501175
#
#                                               geometry
# 0    {'type': 'Point', 'coordinates': [139.751389, ...
# 1    {'type': 'Point', 'coordinates': [121.399722, ...
# 2    {'type': 'Point', 'coordinates': [72.825833, 1...
# 3    {'type': 'Point', 'coordinates': [67.0822, 24....
# 4    {'type': 'Point', 'coordinates': [77.216667, 2...
# ..                                                 ...
# 615  {'type': 'Point', 'coordinates': [86.983333, 2...
# 616  {'type': 'Point', 'coordinates': [49.689164, 3...
# 617  {'type': 'Point', 'coordinates': [48.040756, 4...
# 618  {'type': 'Point', 'coordinates': [113.567778, ...
# 619  {'type': 'Point', 'coordinates': [153.430878, ...
#
# [620 rows x 5 columns]

# %%
cities_df = pd.merge(df, cities_pop_regions, how='left', on='city')
cities_df
# Out:
#             Centre  Rating           city region country  population  \
# 0    New York City   790.0  new york city    NaN     NaN         NaN
# 1           London   773.0         london     H9      gb   7421228.0
# 2        Hong Kong   771.0      hong kong    NaN     NaN         NaN
# 3        Singapore   762.0      singapore     00      sg   3547809.0
# 4         Shanghai   761.0       shanghai     23      cn  14608512.0
# ..             ...     ...            ...    ...     ...         ...
# 300     Birmingham     NaN     birmingham     A7      gb    984336.0
# 301       Adelaide     NaN       adelaide     05      au   1074168.0
# 302      Brisbaine     NaN      brisbaine    NaN     NaN         NaN
# 303          Perth     NaN          perth     08      au   1446715.0
# 304       Auckland     NaN       auckland    NaN     NaN         NaN
#
#                                               geometry
# 0                                                  NaN
# 1    {'type': 'Point', 'coordinates': [-0.093689, 5...
# 2                                                  NaN
# 3    {'type': 'Point', 'coordinates': [103.8558333,...
# 4    {'type': 'Point', 'coordinates': [121.399722, ...
# ..                                                 ...
# 300  {'type': 'Point', 'coordinates': [-1.916667, 5...
# 301  {'type': 'Point', 'coordinates': [138.598633, ...
# 302                                                NaN
# 303  {'type': 'Point', 'coordinates': [115.861397, ...
# 304                                                NaN
#
# [305 rows x 7 columns]

# %%
cities_df.drop(index=cities_df[cities_df.city.duplicated() == True].index, inplace=True)
cities_df
# Out:
#             Centre  Rating           city region country  population  \
# 0    New York City   790.0  new york city    NaN     NaN         NaN
# 1           London   773.0         london     H9      gb   7421228.0
# 2        Hong Kong   771.0      hong kong    NaN     NaN         NaN
# 3        Singapore   762.0      singapore     00      sg   3547809.0
# 4         Shanghai   761.0       shanghai     23      cn  14608512.0
# ..             ...     ...            ...    ...     ...         ...
# 300     Birmingham     NaN     birmingham     A7      gb    984336.0
# 301       Adelaide     NaN       adelaide     05      au   1074168.0
# 302      Brisbaine     NaN      brisbaine    NaN     NaN         NaN
# 303          Perth     NaN          perth     08      au   1446715.0
# 304       Auckland     NaN       auckland    NaN     NaN         NaN
#
#                                               geometry
# 0                                                  NaN
# 1    {'type': 'Point', 'coordinates': [-0.093689, 5...
# 2                                                  NaN
# 3    {'type': 'Point', 'coordinates': [103.8558333,...
# 4    {'type': 'Point', 'coordinates': [121.399722, ...
# ..                                                 ...
# 300  {'type': 'Point', 'coordinates': [-1.916667, 5...
# 301  {'type': 'Point', 'coordinates': [138.598633, ...
# 302                                                NaN
# 303  {'type': 'Point', 'coordinates': [115.861397, ...
# 304                                                NaN
#
# [302 rows x 7 columns]

# %%
cities_df.geometry.value_counts(dropna=False)
# Out:
# NaN                                                           116
# {'type': 'Point', 'coordinates': [19.083333, 47.5]}             1
# {'type': 'Point', 'coordinates': [-3.69222, 40.408566]}         1
# {'type': 'Point', 'coordinates': [-9.133333, 38.716667]}        1
# {'type': 'Point', 'coordinates': [106.552778, 29.562778]}       1
#                                                              ...
# {'type': 'Point', 'coordinates': [67.0822, 24.9056]}            1
# {'type': 'Point', 'coordinates': [12.583333, 55.666667]}        1
# {'type': 'Point', 'coordinates': [32.484636, 37.871354]}        1
# {'type': 'Point', 'coordinates': [-60.639317, -32.946818]}      1
# {'type': 'Point', 'coordinates': [44.3938889, 33.3386111]}      1
# Name: geometry, Length: 187, dtype: int64

# %%
cities_df.city.duplicated?

# %% [markdown]
# ## Generate city grids from geojson boundaries

# %%
def get_nominatim_search_url(city_name):
    """
    Encodes city name and wraps it in openstreetmap request for geospatial city boundaries
    """
    if len(city_name) <= 0:
        return None
    return f"https://nominatim.openstreetmap.org/search.php?q={quote_plus(city_name)}&polygon_geojson=1&format=json"

# %%
def bounds_from_nominatim(geocode_json):
    for g in geocode_json:
        geo_json = g.get('geojson')

        if geo_json and geo_json['type'] in ('Polygon', 'MultiPolygon'):
            return g
    return None

def generate_and_save_city_grid(c, grid_threshold=0.05):
    url = get_nominatim_search_url(c)
    print('url', url)
    
    geocode_data = requests.get(url)
    geocode_json = geocode_data.json()
    
    city_filename = re.sub(r'[^A-Za-z]','',c)

    if len(geocode_json):
        geocode_data = bounds_from_nominatim(geocode_json)
        
        if not geocode_data:
            print('Unable to Find City')
            return
        
        lat = geocode_data['lat']
        lng = geocode_data['lon']

        with open(f'data/{city_filename}.geojson', 'w') as f:
           json.dump(geocode_data['geojson'], f)
        
        geo_df = gpd.read_file(f'data/{city_filename}.geojson')

        grid = generate_square_grid(geo_df.iloc[0]['geometry'], grid_threshold)

        ## apply to feature and feature collection?
        cfs = {
            # TODO
            'city_name': c,
        }

        feature_list = [Feature(geometry=g) for g in grid]
        feature_collection = FeatureCollection(feature_list) 
        
        with open(f'data/{city_filename}_grid.geojson', 'w') as f:
           dump(feature_collection, f)
        
        print('ready to plot', lat, lng, len(grid))
        
        return plot_foursquare_search_grid(lat, lng, grid)

# %%
def generate_city_grid(c, gdf, grid_threshold=0.05):
    
    city_filename = re.sub(r'[^A-Za-z]','',c)

#         with open(f'data/{city_filename}.geojson', 'w') as f:
#            json.dump(geocode_data['geojson'], f)
        
#         geo_df = gpd.read_file(f'data/{city_filename}.geojson')

    grid = generate_square_grid(gdf.geometry, grid_threshold)

    cfs = {'city_name': c}

    feature_list = [Feature(geometry=g) for g in grid]
    feature_collection = FeatureCollection(feature_list) 

    with open(f'data/{city_filename}_districts_grid.geojson', 'w') as f:
       dump(feature_collection, f)

    print('Saved grid to file.')

# %%
[generate_and_save_city_grid(i, 0.05) for i in df.Centre]
# Out:
# url https://nominatim.openstreetmap.org/search.php?q=S%C3%A3o+Paulo&polygon_geojson=1&format=json
# 0.4612008000000003
# 0.6501452000000008
# grid length 87
# ready to plot -23.5506507 -46.6333824 87
# url https://nominatim.openstreetmap.org/search.php?q=Cyprus&polygon_geojson=1&format=json
# 2.832560100000002
# 1.474881400000001
# next threshold 0.1
# grid length 281
# ready to plot 34.9823018 33.1451285 281
# url https://nominatim.openstreetmap.org/search.php?q=Sofia&polygon_geojson=1&format=json
# 0.23167250000000195
# 0.1667065999999977
# grid length 19
# ready to plot 42.6978634 23.3221789 19
# url https://nominatim.openstreetmap.org/search.php?q=Riga&polygon_geojson=1&format=json
# 0.39247310000000013
# 0.22863530000000054
# grid length 35
# ready to plot 56.9493977 24.1051846 35
# url https://nominatim.openstreetmap.org/search.php?q=Panama&polygon_geojson=1&format=json
# 5.893149400000013
# 2.836307800000001
# next threshold 0.2
# grid length 328
# ready to plot 8.559559 -81.1308434 328
# url https://nominatim.openstreetmap.org/search.php?q=Rio+de+Janeiro&polygon_geojson=1&format=json
# 0.6971709000000033
# 0.3366172999999968
# grid length 76
# ready to plot -22.9110137 -43.2093727 76
# url https://nominatim.openstreetmap.org/search.php?q=Nairobi&polygon_geojson=1&format=json
# 0.4529493000000002
# 0.28113900000000003
# grid length 42
# ready to plot -1.2832533 36.8172449 42
# url https://nominatim.openstreetmap.org/search.php?q=Isle+of+Man&polygon_geojson=1&format=json
# 0.48699919999999963
# 0.36391290000000254
# grid length 49
# ready to plot 54.2358167 -4.514598745698255 49
# url https://nominatim.openstreetmap.org/search.php?q=New+Delhi&polygon_geojson=1&format=json
# 0.20476840000000607
# 0.1644209000000032
# grid length 14
# ready to plot 28.6141793 77.2022662 14
# url https://nominatim.openstreetmap.org/search.php?q=Jakarta&polygon_geojson=1&format=json
# 0.6593017999999944
# 1.3750939999999998
# grid length 261
# ready to plot -6.1753942 106.827183 261
# url https://nominatim.openstreetmap.org/search.php?q=Guernsey&polygon_geojson=1&format=json
# 0.9706245
# 0.7204250999999999
# grid length 223
# ready to plot 49.579520200000005 -2.5290434448309886 223
# url https://nominatim.openstreetmap.org/search.php?q=Reykjavik&polygon_geojson=1&format=json
# 0.5818307999999988
# 0.32552279999999456
# grid length 49
# ready to plot 64.24450355 -21.769263572151285 49
# url https://nominatim.openstreetmap.org/search.php?q=Baku&polygon_geojson=1&format=json
# 0.24135659999999604
# 0.14011860000000098
# grid length 15
# ready to plot 40.3754434 49.8326748 15
# url https://nominatim.openstreetmap.org/search.php?q=Malta&polygon_geojson=1&format=json
# 0.8943739999999991
# 0.6823009999999954
# grid length 201
# ready to plot 35.8885993 14.4476911 201
# url https://nominatim.openstreetmap.org/search.php?q=Riyadh&polygon_geojson=1&format=json
# 0.017358500000000276
# 0.017739900000000475
# grid length 1
# ready to plot 15.57617585 32.568864532939294 1
# url https://nominatim.openstreetmap.org/search.php?q=Manila&polygon_geojson=1&format=json
# 0.08447530000000825
# 0.08482260000000075
# grid length 6
# ready to plot 14.5970139 120.98397806987128 6
# url https://nominatim.openstreetmap.org/search.php?q=Almaty&polygon_geojson=1&format=json
# 0.4284764000000081
# 0.3708410999999998
# grid length 57
# ready to plot 43.219842549999996 76.91835188749678 57
# url https://nominatim.openstreetmap.org/search.php?q=Santiago&polygon_geojson=1&format=json
# 0.07850959999998963
# 0.07652250000000116
# grid length 5
# ready to plot 9.8694792 -83.7980749 5
# url https://nominatim.openstreetmap.org/search.php?q=Athens&polygon_geojson=1&format=json
# 0.5766300000000086
# 0.3761703000000054
# grid length 82
# ready to plot 39.355589 -82.0610404 82
# url https://nominatim.openstreetmap.org/search.php?q=Dalian&polygon_geojson=1&format=json
# 2.542027500000003
# 1.4826485999999974
# next threshold 0.1
# grid length 223
# ready to plot 39.740278 122.255833 223
# url https://nominatim.openstreetmap.org/search.php?q=Tianjin&polygon_geojson=1&format=json
# 1.3577994999999987
# 1.697058399999996
# grid length 629
# ready to plot 39.3032619 117.4163641 629
# url https://nominatim.openstreetmap.org/search.php?q=Nanjing&polygon_geojson=1&format=json
# 0.8814804000000009
# 1.385577399999999
# grid length 329
# ready to plot 32.0609736 118.7916458 329
# url https://nominatim.openstreetmap.org/search.php?q=Hangzhou&polygon_geojson=1&format=json
# 2.3731600999999927
# 1.3760227999999977
# next threshold 0.1
# grid length 206
# ready to plot 30.2489634 120.2052342 206
# [<folium.folium.Map at 0x1a30b3f490>,
#  <folium.folium.Map at 0x121cd5f10>,
#  <folium.folium.Map at 0x1a309fb790>,
#  <folium.folium.Map at 0x1a2f4c3710>,
#  <folium.folium.Map at 0x1a30ae5cd0>,
#  <folium.folium.Map at 0x1a30f59190>,
#  <folium.folium.Map at 0x111f063d0>,
#  <folium.folium.Map at 0x1a2f4cb0d0>,
#  <folium.folium.Map at 0x1a3081e590>,
#  <folium.folium.Map at 0x1a30aa8d50>,
#  <folium.folium.Map at 0x1a30ac3110>,
#  <folium.folium.Map at 0x1a30b15710>,
#  <folium.folium.Map at 0x1a3114f690>,
#  <folium.folium.Map at 0x1a30f11310>,
#  <folium.folium.Map at 0x1a311627d0>,
#  <folium.folium.Map at 0x1a30c59c90>,
#  <folium.folium.Map at 0x1a3103da10>,
#  <folium.folium.Map at 0x1a315571d0>,
#  <folium.folium.Map at 0x1a31a5eed0>,
#  <folium.folium.Map at 0x1a31578d90>,
#  <folium.folium.Map at 0x1a30fb4f10>,
#  <folium.folium.Map at 0x1a31acb810>,
#  <folium.folium.Map at 0x1a31a22a90>]

# %%
[generate_and_save_city_grid(i, 0.05) for i in non_financial_cities.iloc[40:,0]]
# Out:
# url https://nominatim.openstreetmap.org/search.php?q=Ouagadougou&polygon_geojson=1&format=json
# 0.24668749999999995
# 0.23992469999999955
# grid length 28
# ready to plot 12.3704741 -1.5334099725592838 28
# url https://nominatim.openstreetmap.org/search.php?q=Abidjan&polygon_geojson=1&format=json
# 0.5763377000000003
# 0.41545589999999955
# grid length 91
# ready to plot 5.4091179 -4.0422099 91
# url https://nominatim.openstreetmap.org/search.php?q=Addis+Ababa&polygon_geojson=1&format=json
# 0.2545999999999964
# 0.2663808000000003
# grid length 28
# ready to plot 9 38.75 28
# url https://nominatim.openstreetmap.org/search.php?q=Kumasi&polygon_geojson=1&format=json
# 0.0003641999999999257
# 0.00035929999999950724
# grid length 1
# ready to plot 49.192787100000004 -2.123797886441899 1
# url https://nominatim.openstreetmap.org/search.php?q=Conakry&polygon_geojson=1&format=json
# 0.3664709999999989
# 0.3211756000000001
# grid length 32
# ready to plot 9.6216542 -13.559258646382819 32
# url https://nominatim.openstreetmap.org/search.php?q=Nairobi&polygon_geojson=1&format=json
# 0.4529493000000002
# 0.28113900000000003
# grid length 42
# ready to plot -1.2832533 36.8172449 42
# url https://nominatim.openstreetmap.org/search.php?q=Antananarivo&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=F%C3%A8s&polygon_geojson=1&format=json
# 0.1404689999999995
# 0.09907700000000119
# grid length 12
# ready to plot 34.0346534 -5.0161926 12
# url https://nominatim.openstreetmap.org/search.php?q=Maputo&polygon_geojson=1&format=json
# 0.5564058000000003
# 0.4798435999999988
# grid length 70
# ready to plot -26.0476384 32.79404891502372 70
# url https://nominatim.openstreetmap.org/search.php?q=Niamey&polygon_geojson=1&format=json
# 0.25413030000000014
# 0.1996804000000001
# grid length 21
# ready to plot 13.4998139 2.1094859721216785 21
# url https://nominatim.openstreetmap.org/search.php?q=Dakar&polygon_geojson=1&format=json
# 0.4284144999999988
# 0.2978252000000001
# grid length 41
# ready to plot 14.74053735 -17.333928539102963 41
# url https://nominatim.openstreetmap.org/search.php?q=Freetown&polygon_geojson=1&format=json
# 0.21372420000000147
# 0.10601150000000104
# grid length 10
# ready to plot 41.7944569 -71.0655834 10
# url https://nominatim.openstreetmap.org/search.php?q=Mogadishu&polygon_geojson=1&format=json
# 0.1933216999999985
# 0.12211380000000016
# grid length 11
# ready to plot 2.042778 45.338564 11
# url https://nominatim.openstreetmap.org/search.php?q=Kampala&polygon_geojson=1&format=json
# 0.15886600000000328
# 0.1914109
# grid length 14
# ready to plot 0.3177137 32.5813539 14
# url https://nominatim.openstreetmap.org/search.php?q=Dar+es+Salaam&polygon_geojson=1&format=json
# 0.9250173000000004
# 0.6206477000000001
# grid length 89
# ready to plot -6.876348 39.29800932882965 89
# url https://nominatim.openstreetmap.org/search.php?q=Lusaka&polygon_geojson=1&format=json
# 0.00785659999999666
# 0.021130300000001156
# grid length 1
# ready to plot -8.486764950000001 32.02354247339338 1
# url https://nominatim.openstreetmap.org/search.php?q=Harare&polygon_geojson=1&format=json
# 0.3440258000000007
# 0.39382839999999675
# grid length 52
# ready to plot -17.8567035 31.0601584 52
# url https://nominatim.openstreetmap.org/search.php?q=Calgary&polygon_geojson=1&format=json
# 0.45575689999999724
# 0.3699753000000001
# grid length 64
# ready to plot 51.0534234 -114.0625892 64
# url https://nominatim.openstreetmap.org/search.php?q=Montr%C3%A9al&polygon_geojson=1&format=json
# 0.4998614999999944
# 0.2947141000000002
# grid length 40
# ready to plot 45.4972159 -73.6103642 40
# url https://nominatim.openstreetmap.org/search.php?q=Havana&polygon_geojson=1&format=json
# 0.010589000000010174
# 0.007989000000002022
# grid length 1
# ready to plot 37.0923595 -95.94282618847157 1
# url https://nominatim.openstreetmap.org/search.php?q=Santo+Domingo&polygon_geojson=1&format=json
# 0.4654462999999964
# 0.31485490000000027
# grid length 52
# ready to plot 22.64121075 -80.33826956731188 52
# url https://nominatim.openstreetmap.org/search.php?q=Tegucigalpa&polygon_geojson=1&format=json
# 0.14632380000000467
# 0.13537940000000148
# grid length 12
# ready to plot 14.0739886 -87.20698382932179 12
# url https://nominatim.openstreetmap.org/search.php?q=Guadalajara&polygon_geojson=1&format=json
# 0.1433028999999948
# 0.1488997000000012
# grid length 12
# ready to plot 20.67826135 -103.33576479630055 12
# url https://nominatim.openstreetmap.org/search.php?q=Ju%C3%A1rez&polygon_geojson=1&format=json
# 0.7707430000000102
# 0.6639413000000012
# grid length 167
# ready to plot 31.452227450000002 -106.44972558551015 167
# url https://nominatim.openstreetmap.org/search.php?q=La+Laguna&polygon_geojson=1&format=json
# 0.14373149999999768
# 0.14756630000000115
# grid length 12
# ready to plot 28.4857715 -16.3159422 12
# url https://nominatim.openstreetmap.org/search.php?q=Le%C3%B3n&polygon_geojson=1&format=json
# 2.3446887
# 1.2093552999999986
# next threshold 0.1
# grid length 214
# ready to plot 31.2715127 -95.9953382 214
# url https://nominatim.openstreetmap.org/search.php?q=Monterrey&polygon_geojson=1&format=json
# 0.2741996000000029
# 0.3152660999999988
# grid length 24
# ready to plot 25.63978365 -100.29310162906569 24
# url https://nominatim.openstreetmap.org/search.php?q=Puebla-Tlaxcala&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Quer%C3%A9taro&polygon_geojson=1&format=json
# 1.553455800000009
# 1.6549872000000008
# grid length 489
# ready to plot 20.8542575 -99.84756 489
# url https://nominatim.openstreetmap.org/search.php?q=San+Luis+Potos%C3%AD-Soledad+de+Graciano+S%C3%A1nchez&polygon_geojson=1&format=json
# 0.21271510000001115
# 0.32020239999999944
# grid length 24
# ready to plot 22.297055450000002 -100.86719560926427 24
# url https://nominatim.openstreetmap.org/search.php?q=Tijuana&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Toluca&polygon_geojson=1&format=json
# 0.2536994999999962
# 0.41581210000000013
# grid length 29
# ready to plot 19.2842743 -99.65263421776106 29
# url https://nominatim.openstreetmap.org/search.php?q=Philadelphia&polygon_geojson=1&format=json
# 0.32446630000001164
# 0.27095429999999965
# grid length 30
# ready to plot 39.9527237 -75.1635262 30
# url https://nominatim.openstreetmap.org/search.php?q=Phoenix&polygon_geojson=1&format=json
# 0.3985088000000019
# 0.6280055000000004
# grid length 86
# ready to plot 33.4484367 -112.0741417 86
# url https://nominatim.openstreetmap.org/search.php?q=San+Antonio&polygon_geojson=1&format=json
# 0.5901836000000031
# 0.5447051000000016
# grid length 90
# ready to plot 29.4246002 -98.4951405 90
# url https://nominatim.openstreetmap.org/search.php?q=San+Diego&polygon_geojson=1&format=json
# 0.40408269999998936
# 0.5794651000000002
# grid length 71
# ready to plot 32.7174209 -117.1627714 71
# url https://nominatim.openstreetmap.org/search.php?q=C%C3%B3rdoba&polygon_geojson=1&format=json
# 0.6471710999999996
# 0.36569430000000125
# grid length 75
# ready to plot 37.8845813 -4.7760138 75
# url https://nominatim.openstreetmap.org/search.php?q=Mendoza&polygon_geojson=1&format=json
# 4.105728199999987
# 5.575510600000001
# next threshold 0.2
# grid length 425
# ready to plot -34.78719615 -68.43807123826872 425
# url https://nominatim.openstreetmap.org/search.php?q=Rosario&polygon_geojson=1&format=json
# 0.1715927999999991
# 0.1652130000000014
# grid length 13
# ready to plot -32.9595004 -60.6615415 13
# url https://nominatim.openstreetmap.org/search.php?q=Santa+Cruz&polygon_geojson=1&format=json
# 0.22644550000000052
# 0.1956643999999983
# grid length 15
# ready to plot 28.469648 -16.2540884 15
# url https://nominatim.openstreetmap.org/search.php?q=Bel%C3%A9m&polygon_geojson=1&format=json
# 0.32811489999999566
# 0.5158544999999999
# grid length 56
# ready to plot -1.45056 -48.4682453 56
# url https://nominatim.openstreetmap.org/search.php?q=Belo+Horizonte&polygon_geojson=1&format=json
# 0.20607170000000252
# 0.28292089999999703
# grid length 24
# ready to plot -19.9227318 -43.9450948 24
# url https://nominatim.openstreetmap.org/search.php?q=Campinas&polygon_geojson=1&format=json
# 0.43102919999999756
# 0.33216979999999907
# grid length 48
# ready to plot -22.90556 -47.06083 48
# url https://nominatim.openstreetmap.org/search.php?q=Fortaleza&polygon_geojson=1&format=json
# 0.23658189999999735
# 0.20243940000000027
# grid length 19
# ready to plot -3.7304512 -38.5217989 19
# url https://nominatim.openstreetmap.org/search.php?q=Guarulhos&polygon_geojson=1&format=json
# 0.2351109999999963
# 0.2363509999999991
# grid length 23
# ready to plot -23.4430602 -46.524459 23
# url https://nominatim.openstreetmap.org/search.php?q=Manaus&polygon_geojson=1&format=json
# 1.6410000000000053
# 1.298
# grid length 435
# ready to plot -3.1316333 -59.9825041 435
# url https://nominatim.openstreetmap.org/search.php?q=Salvador&polygon_geojson=1&format=json
# 2.5439580999999976
# 1.4750028000000004
# next threshold 0.1
# grid length 260
# ready to plot 13.8000382 -88.9140683 260
# url https://nominatim.openstreetmap.org/search.php?q=Barranquilla&polygon_geojson=1&format=json
# 0.16438970000000097
# 0.1914415999999992
# grid length 14
# ready to plot 11.011848449999999 -74.80886011839334 14
# url https://nominatim.openstreetmap.org/search.php?q=Cali&polygon_geojson=1&format=json
# 0.24804589999999394
# 0.2751684999999999
# grid length 30
# ready to plot 3.4108435 -76.58121271109312 30
# url https://nominatim.openstreetmap.org/search.php?q=Cartagena&polygon_geojson=1&format=json
# 0.5789875000000001
# 0.19701880000000216
# grid length 44
# ready to plot 37.6267868 -1.0006184 44
# url https://nominatim.openstreetmap.org/search.php?q=Medell%C3%ADn&polygon_geojson=1&format=json
# 0.24596579999999335
# 0.20933970000000013
# grid length 24
# ready to plot 6.27162785 -75.60281325266426 24
# url https://nominatim.openstreetmap.org/search.php?q=Esmeraldas&polygon_geojson=1&format=json
# 0.37873189999999823
# 0.36895609999999834
# grid length 51
# ready to plot -19.7613111 -44.3145945 51
# url https://nominatim.openstreetmap.org/search.php?q=QUITO&polygon_geojson=1&format=json
# 0.07047660000000633
# 0.1039156
# grid length 5
# ready to plot -0.4108905 -78.51928249506524 5
# url https://nominatim.openstreetmap.org/search.php?q=Montevideo&polygon_geojson=1&format=json
# 0.4088990999999993
# 0.23620340000000084
# grid length 37
# ready to plot -34.9059039 -56.1913569 37
# url https://nominatim.openstreetmap.org/search.php?q=Caracas&polygon_geojson=1&format=json
# 0.031516300000006936
# 0.025365900000000607
# grid length 2
# ready to plot 4.931658649999999 -75.74872878365295 2
# url https://nominatim.openstreetmap.org/search.php?q=Maracaibo&polygon_geojson=1&format=json
# 0.002096399999999221
# 0.0020183999999998647
# grid length 1
# ready to plot 3.4185565 -76.5171158075899 1
# url https://nominatim.openstreetmap.org/search.php?q=Kabul+Center&polygon_geojson=1&format=json
# 1.1103440999999918
# 0.761946199999997
# grid length 229
# ready to plot 34.5 69.416667 229
# url https://nominatim.openstreetmap.org/search.php?q=Yerevan&polygon_geojson=1&format=json
# 0.2344647999999978
# 0.19672489999999954
# grid length 20
# ready to plot 40.16431325 44.53173297196527 20
# url https://nominatim.openstreetmap.org/search.php?q=Baku&polygon_geojson=1&format=json
# 0.24135659999999604
# 0.14011860000000098
# grid length 15
# ready to plot 40.3754434 49.8326748 15
# url https://nominatim.openstreetmap.org/search.php?q=Chittagong&polygon_geojson=1&format=json
# 2.1411542000000026
# 3.9007870999999987
# next threshold 0.1
# grid length 420
# ready to plot 22.325977350000002 92.11871858853561 420
# url https://nominatim.openstreetmap.org/search.php?q=Phnom+Penh&polygon_geojson=1&format=json
# 0.3286520000000053
# 0.3033994999999994
# grid length 38
# ready to plot 11.5742555 104.8289322473223 38
# url https://nominatim.openstreetmap.org/search.php?q=Bat+Dambang&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Tbilisi&polygon_geojson=1&format=json
# 0.42087490000000116
# 0.22302599999999728
# grid length 39
# ready to plot 41.73188365 44.8368762993663 39
# url https://nominatim.openstreetmap.org/search.php?q=Agra&polygon_geojson=1&format=json
# 1.4557662999999934
# 0.6684459999999994
# grid length 218
# ready to plot 27.0767237 77.87559052319853 218
# url https://nominatim.openstreetmap.org/search.php?q=Amritsar&polygon_geojson=1&format=json
# 0.9175398000000001
# 0.5639073000000003
# grid length 141
# ready to plot 31.7732179 74.83168503488656 141
# url https://nominatim.openstreetmap.org/search.php?q=Aurangabad&polygon_geojson=1&format=json
# 0.5162716000000103
# 0.3705564000000017
# grid length 67
# ready to plot 19.8480821 75.43654421835765 67
# url https://nominatim.openstreetmap.org/search.php?q=Bhopal&polygon_geojson=1&format=json
# 0.4827674000000002
# 0.8229872
# grid length 133
# ready to plot 23.4851136 77.39305106355064 133
# url https://nominatim.openstreetmap.org/search.php?q=Dhanbad&polygon_geojson=1&format=json
# 0.7179308000000049
# 0.42853799999999964
# grid length 97
# ready to plot 23.7963432 86.4291983 97
# url https://nominatim.openstreetmap.org/search.php?q=Indore&polygon_geojson=1&format=json
# 0.8215069999999969
# 0.7566718999999971
# grid length 178
# ready to plot 22.71113445 75.80768747988787 178
# url https://nominatim.openstreetmap.org/search.php?q=Kalyan+Dombivali&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Kanpur&polygon_geojson=1&format=json
# 0.46880250000000956
# 0.46389059999999915
# grid length 59
# ready to plot 26.40807935 80.29276819560538 59
# url https://nominatim.openstreetmap.org/search.php?q=Calcutta&polygon_geojson=1&format=json
# 0.10254279999999483
# 0.07189299999999577
# grid length 6
# ready to plot 40.673397 -80.5764592 6
# url https://nominatim.openstreetmap.org/search.php?q=Lucknow&polygon_geojson=1&format=json
# 0.6661188999999865
# 0.655723100000003
# grid length 124
# ready to plot 26.831180449999998 80.91345396441672 124
# url https://nominatim.openstreetmap.org/search.php?q=Ludhiana&polygon_geojson=1&format=json
# 0.9681128000000001
# 0.45770100000000014
# grid length 179
# ready to plot 30.7882441 75.82645714120757 179
# url https://nominatim.openstreetmap.org/search.php?q=Meerut&polygon_geojson=1&format=json
# 0.7015564000000012
# 0.5297733000000022
# grid length 132
# ready to plot 28.916667 77.683333 132
# url https://nominatim.openstreetmap.org/search.php?q=Nagpur&polygon_geojson=1&format=json
# 1.4057349999999929
# 1.1386623
# grid length 405
# ready to plot 21.15254625 79.01437895115814 405
# url https://nominatim.openstreetmap.org/search.php?q=Nashik&polygon_geojson=1&format=json
# 1.6854573000000102
# 1.279288900000001
# grid length 623
# ready to plot 20.2239357 74.10599994335189 623
# url https://nominatim.openstreetmap.org/search.php?q=Patna&polygon_geojson=1&format=json
# 1.382324699999998
# 0.5284033000000008
# grid length 165
# ready to plot 25.46737665 85.19581528126407 165
# url https://nominatim.openstreetmap.org/search.php?q=Pimpri+Chinchwad&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Rajkot&polygon_geojson=1&format=json
# 1.4774464999999992
# 1.0846434999999985
# grid length 346
# ready to plot 22.068582900000003 71.02964534617706 346
# url https://nominatim.openstreetmap.org/search.php?q=Srinagar&polygon_geojson=1&format=json
# 0.172133400000007
# 0.16324619999999967
# grid length 12
# ready to plot 25.90912705 87.39696401432835 12
# url https://nominatim.openstreetmap.org/search.php?q=Thane&polygon_geojson=1&format=json
# 0.0931211999999988
# 0.12649180000000015
# grid length 8
# ready to plot 19.1943294 72.9701779 8
# url https://nominatim.openstreetmap.org/search.php?q=Vadodara&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Vasai-Virar+City&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Batam&polygon_geojson=1&format=json
# 0.719313200000002
# 0.7421745
# grid length 99
# ready to plot 1.1061034 104.0378246 99
# url https://nominatim.openstreetmap.org/search.php?q=Bogor&polygon_geojson=1&format=json
# 0.0010449000000107844
# 0.0019191000000002845
# grid length 1
# ready to plot -6.5943109 106.79084611007264 1
# url https://nominatim.openstreetmap.org/search.php?q=Makasar&polygon_geojson=1&format=json
# 0.04985109999999793
# 0.060507300000000264
# grid length 4
# ready to plot -6.26958695 106.88869732007157 4
# url https://nominatim.openstreetmap.org/search.php?q=Medan&polygon_geojson=1&format=json
# 0.15405269999999405
# 0.30939960000000033
# grid length 23
# ready to plot 3.5896654 98.6738261 23
# url https://nominatim.openstreetmap.org/search.php?q=Surabaya&polygon_geojson=1&format=json
# 0.255229099999994
# 0.1672096999999999
# grid length 21
# ready to plot -7.2459717 112.7378266 21
# url https://nominatim.openstreetmap.org/search.php?q=Tangerang&polygon_geojson=1&format=json
# 0.3878240999999889
# 0.3616228999999995
# grid length 56
# ready to plot -6.1734808 106.4992042 56
# url https://nominatim.openstreetmap.org/search.php?q=Ahwaz&polygon_geojson=1&format=json
# 0.31442159999999575
# 0.4079025000000023
# grid length 40
# ready to plot 31.32628875 48.74431395696944 40
# url https://nominatim.openstreetmap.org/search.php?q=Esfahan&polygon_geojson=1&format=json
# 5.860543399999997
# 3.8100105000000006
# next threshold 0.2
# grid length 320
# ready to plot 33.196733 52.504026 320
# url https://nominatim.openstreetmap.org/search.php?q=Karaj&polygon_geojson=1&format=json
# 0.29005569999999636
# 0.13308500000000123
# grid length 16
# ready to plot 35.8228964 50.95876430889608 16
# url https://nominatim.openstreetmap.org/search.php?q=Mashhad&polygon_geojson=1&format=json
# 0.3041680999999983
# 0.3143703000000002
# grid length 32
# ready to plot 36.29275685 59.57965157590017 32
# url https://nominatim.openstreetmap.org/search.php?q=Qom&polygon_geojson=1&format=json
# 0.16551880000000097
# 0.1535306000000034
# grid length 12
# ready to plot 34.6093841 50.874387005180644 12
# url https://nominatim.openstreetmap.org/search.php?q=Tabriz&polygon_geojson=1&format=json
# 0.22828030000000155
# 0.14111000000000473
# grid length 17
# ready to plot 38.0859873 46.31381891907882 17
# url https://nominatim.openstreetmap.org/search.php?q=Al-Basrah+Qadha+Center&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Al-Mosal+Qadha+Center&polygon_geojson=1&format=json
# url https://nominatim.openstreetmap.org/search.php?q=Jerusalem&polygon_geojson=1&format=json
# 0.1088390999999973
# 0.1426821000000018
# grid length 10
# ready to plot 31.778345 35.2250786 10
# url https://nominatim.openstreetmap.org/search.php?q=Fukuoka&polygon_geojson=1&format=json
# 1.436185800000004
# 1.707760300000004
# grid length 538
# ready to plot 33.6251241 130.6180016 538
# url https://nominatim.openstreetmap.org/search.php?q=Kobe&polygon_geojson=1&format=json
# 0.4197035999999912
# 0.3581671999999969
# grid length 50
# ready to plot 34.6932379 135.1943764 50
# url https://nominatim.openstreetmap.org/search.php?q=Kawasaki&polygon_geojson=1&format=json
# 0.4550698000000182
# 0.23125210000000607
# grid length 24
# ready to plot 35.523142 139.708024 24
# url https://nominatim.openstreetmap.org/search.php?q=Kyoto&polygon_geojson=1&format=json
# 0.31943599999999606
# 0.4463046999999989
# grid length 53
# ready to plot 35.021041 135.7556075 53
# url https://nominatim.openstreetmap.org/search.php?q=Sapporo&polygon_geojson=1&format=json
# 0.5149190000000203
# 0.40928799999999654
# grid length 75
# ready to plot 43.061936 141.3542924 75
# url https://nominatim.openstreetmap.org/search.php?q=Yokohama&polygon_geojson=1&format=json
# 0.31215380000000437
# 0.28023720000000196
# grid length 35
# ready to plot 35.444991 139.636768 35
# url https://nominatim.openstreetmap.org/search.php?q=Amman&polygon_geojson=1&format=json
# 0.0046134000000037645
# 0.007054499999995301
# grid length 1
# ready to plot 31.9515694 35.9239625 1
# url https://nominatim.openstreetmap.org/search.php?q=Astana&polygon_geojson=1&format=json
# 0.5607498999999905
# 0.3504335000000012
# grid length 63
# ready to plot 51.1282205 71.4306682 63
# url https://nominatim.openstreetmap.org/search.php?q=Ulannbaatar&polygon_geojson=1&format=json
# url https://nominatim.openstreetmap.org/search.php?q=Mandalay&polygon_geojson=1&format=json
# 2.0662537000000043
# 3.490740200000001
# next threshold 0.1
# grid length 348
# ready to plot 21.9392622 96.41336372756099 348
# url https://nominatim.openstreetmap.org/search.php?q=Yangon&polygon_geojson=1&format=json
# 0.37404820000000427
# 0.4987724
# grid length 59
# ready to plot 16.7967129 96.1609916 59
# url https://nominatim.openstreetmap.org/search.php?q=Kathmandu&polygon_geojson=1&format=json
# 0.10745130000000813
# 0.08339020000000019
# grid length 7
# ready to plot 27.709913550000003 85.32474911622879 7
# url https://nominatim.openstreetmap.org/search.php?q=Caloocan&polygon_geojson=1&format=json
# 0.1384779999999921
# 0.14976060000000047
# grid length 7
# ready to plot 14.74712915 121.04331622565046 7
# url https://nominatim.openstreetmap.org/search.php?q=Davao&polygon_geojson=1&format=json
# 0.4828401999999983
# 0.7407821000000006
# grid length 109
# ready to plot 7.0644576 125.6083647 109
# url https://nominatim.openstreetmap.org/search.php?q=Quezon+City&polygon_geojson=1&format=json
# 0.14410820000000513
# 0.18704470000000128
# grid length 13
# ready to plot 14.68215105 121.06374285630028 13
# url https://nominatim.openstreetmap.org/search.php?q=Busan&polygon_geojson=1&format=json
# 0.7321455000000014
# 0.6639732000000009
# grid length 111
# ready to plot 35.1799528 129.0752365 111
# url https://nominatim.openstreetmap.org/search.php?q=Daegu&polygon_geojson=1&format=json
# 0.411214799999982
# 0.40973410000000143
# grid length 56
# ready to plot 35.8713 128.6018 56
# url https://nominatim.openstreetmap.org/search.php?q=Incheon&polygon_geojson=1&format=json
# 2.420891299999994
# 1.1955806999999936
# next threshold 0.1
# grid length 143
# ready to plot 37.456 126.7052 143
# url https://nominatim.openstreetmap.org/search.php?q=Ulsan&polygon_geojson=1&format=json
# 0.749883600000004
# 0.5383193999999989
# grid length 117
# ready to plot 35.5391697 129.3119136 117
# url https://nominatim.openstreetmap.org/search.php?q=Jiddah&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Makkah&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Aleppo&polygon_geojson=1&format=json
# 2.1394426000000024
# 1.5399715
# next threshold 0.1
# grid length 247
# ready to plot 36.1526346 37.4111177022524 247
# url https://nominatim.openstreetmap.org/search.php?q=Hama&polygon_geojson=1&format=json
# 2.168319199999999
# 0.9064416000000008
# next threshold 0.1
# grid length 145
# ready to plot 35.2985332 37.2721381403811 145
# url https://nominatim.openstreetmap.org/search.php?q=Homs&polygon_geojson=1&format=json
# 4.050130600000003
# 2.2682755999999955
# next threshold 0.1
# grid length 559
# ready to plot 34.255694000000005 38.302426629912866 559
# url https://nominatim.openstreetmap.org/search.php?q=Idleb&polygon_geojson=1&format=json
# 0.0009897000000052003
# 0.0009762999999978206
# grid length 1
# ready to plot 35.9333588 36.64206218587738 1
# url https://nominatim.openstreetmap.org/search.php?q=Chon+Buri&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Samut+Prakan&polygon_geojson=1&format=json
# 0.5190481000000062
# 0.5018239000000015
# grid length 93
# ready to plot 13.3479081 100.62777366214462 93
# url https://nominatim.openstreetmap.org/search.php?q=Adana&polygon_geojson=1&format=json
# 1.6702817000000039
# 2.141560500000004
# next threshold 0.1
# grid length 217
# ready to plot 37.1438001 35.4984094 217
# url https://nominatim.openstreetmap.org/search.php?q=Antalya&polygon_geojson=1&format=json
# 3.365055400000003
# 1.3335713000000027
# next threshold 0.1
# grid length 267
# ready to plot 36.9279654 30.7276865 267
# url https://nominatim.openstreetmap.org/search.php?q=Bal%C4%B1kesir&polygon_geojson=1&format=json
# 2.5677270000000014
# 1.7249581999999961
# next threshold 0.1
# grid length 240
# ready to plot 39.5400798 28.0228793 240
# url https://nominatim.openstreetmap.org/search.php?q=Bursa&polygon_geojson=1&format=json
# 1.8031062999999996
# 1.1501582
# grid length 602
# ready to plot 39.9895878 28.8944669 602
# url https://nominatim.openstreetmap.org/search.php?q=Diyarbakir&polygon_geojson=1&format=json
# 2.2600412999999975
# 1.226869800000003
# next threshold 0.1
# grid length 198
# ready to plot 38.0814716 40.4297767 198
# url https://nominatim.openstreetmap.org/search.php?q=Izmir&polygon_geojson=1&format=json
# 2.2969592
# 1.5702567000000016
# next threshold 0.1
# grid length 218
# ready to plot 38.23166 27.02997 218
# url https://nominatim.openstreetmap.org/search.php?q=Gaziantep&polygon_geojson=1&format=json
# 1.6382509000000027
# 0.8179589999999948
# grid length 342
# ready to plot 36.9666307 37.4074178 342
# url https://nominatim.openstreetmap.org/search.php?q=Hatay&polygon_geojson=1&format=json
# 0.9152375000000035
# 1.2005304999999993
# grid length 282
# ready to plot 36.2025939 36.1603945 282
# url https://nominatim.openstreetmap.org/search.php?q=Kocaeli&polygon_geojson=1&format=json
# 1.196000299999998
# 0.8922041000000007
# grid length 255
# ready to plot 40.8216536 29.9507184 255
# url https://nominatim.openstreetmap.org/search.php?q=Konya&polygon_geojson=1&format=json
# 3.1779607000000034
# 2.522838700000001
# next threshold 0.1
# grid length 501
# ready to plot 38.0211951 32.5224943 501
# url https://nominatim.openstreetmap.org/search.php?q=Manisa&polygon_geojson=1&format=json
# 2.0178152999999988
# 1.3218154999999996
# next threshold 0.1
# grid length 173
# ready to plot 38.8574402 28.0565711 173
# url https://nominatim.openstreetmap.org/search.php?q=Mersin&polygon_geojson=1&format=json
# 2.7565490999999938
# 1.618600899999997
# next threshold 0.1
# grid length 272
# ready to plot 36.8328277 33.9685895 272
# url https://nominatim.openstreetmap.org/search.php?q=Sanliurfa&polygon_geojson=1&format=json
# 2.403280600000002
# 1.3514142999999947
# next threshold 0.1
# grid length 238
# ready to plot 37.2595198 39.0408174 238
# url https://nominatim.openstreetmap.org/search.php?q=Tashkent&polygon_geojson=1&format=json
# 0.351638400000013
# 0.25339479999999526
# grid length 29
# ready to plot 41.283974549999996 69.25598969313666 29
# url https://nominatim.openstreetmap.org/search.php?q=Sana%27a&polygon_geojson=1&format=json
# 0.1735327999999967
# 0.23821200000000076
# grid length 20
# ready to plot 15.3538569 44.2058841 20
# url https://nominatim.openstreetmap.org/search.php?q=Wien&polygon_geojson=1&format=json
# 0.39568219999999954
# 0.20476099999999775
# grid length 36
# ready to plot 48.2202097 16.371215973799906 36
# url https://nominatim.openstreetmap.org/search.php?q=Minsk&polygon_geojson=1&format=json
# 0.6868821000000018
# 0.17794270000000267
# grid length 43
# ready to plot 53.902334 27.5618791 43
# url https://nominatim.openstreetmap.org/search.php?q=Zagreb&polygon_geojson=1&format=json
# 0.2816549999999989
# 0.19067400000000134
# grid length 26
# ready to plot 45.813177 15.977048 26
# url https://nominatim.openstreetmap.org/search.php?q=Praha&polygon_geojson=1&format=json
# 0.4823512000000001
# 0.2355295000000055
# grid length 43
# ready to plot 50.0874654 14.4212535 43
# url https://nominatim.openstreetmap.org/search.php?q=Lille&polygon_geojson=1&format=json
# 0.1577573000000001
# 0.06043319999999852
# grid length 8
# ready to plot 50.6365654 3.0635282 8
# url https://nominatim.openstreetmap.org/search.php?q=Marseille&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=M%C3%BCnchen&polygon_geojson=1&format=json
# 0.3621312999999997
# 0.18649179999999888
# grid length 28
# ready to plot 48.1371079 11.5753822 28
# url https://nominatim.openstreetmap.org/search.php?q=Bucharest&polygon_geojson=1&format=json
# 0.2618750999999975
# 0.20716279999999898
# grid length 21
# ready to plot 44.437913949999995 26.086358482531296 21
# url https://nominatim.openstreetmap.org/search.php?q=Ekaterinburg&polygon_geojson=1&format=json
# 0.47748830000000453
# 0.24575990000000303
# grid length 40
# ready to plot 56.839104 60.60825 40
# url https://nominatim.openstreetmap.org/search.php?q=Kazan&polygon_geojson=1&format=json
# 0.5606623000000042
# 0.33474139999999863
# grid length 61
# ready to plot 55.7823547 49.1242266 61
# url https://nominatim.openstreetmap.org/search.php?q=Nizhny+Novgorod&polygon_geojson=1&format=json
# 0.3849117000000035
# 0.21432859999999465
# grid length 36
# ready to plot 56.328571 44.003506 36
# url https://nominatim.openstreetmap.org/search.php?q=Novosibirsk&polygon_geojson=1&format=json
# 0.4090951000000018
# 0.33391340000000014
# grid length 45
# ready to plot 55.0282171 82.9234509 45
# url https://nominatim.openstreetmap.org/search.php?q=Omsk&polygon_geojson=1&format=json
# 0.5624158999999906
# 0.6025248000000047
# grid length 69
# ready to plot 54.991375 73.371529 69
# url https://nominatim.openstreetmap.org/search.php?q=Ufa&polygon_geojson=1&format=json
# 0.000929300000001021
# 0.0004632999999998333
# grid length 1
# ready to plot 52.38706125 13.122811699203996 1
# url https://nominatim.openstreetmap.org/search.php?q=Belgrade&polygon_geojson=1&format=json
# 0.8777374000000009
# 0.8342317000000037
# grid length 196
# ready to plot 44.8178131 20.4568974 196
# url https://nominatim.openstreetmap.org/search.php?q=Barcelona&polygon_geojson=1&format=json
# 0.17585780000000018
# 0.15087820000000107
# grid length 12
# ready to plot 41.3828939 2.1774322 12
# url https://nominatim.openstreetmap.org/search.php?q=Kharkiv&polygon_geojson=1&format=json
# 0.349932299999999
# 0.22627109999999817
# grid length 32
# ready to plot 49.9902794 36.2303893 32
# url https://nominatim.openstreetmap.org/search.php?q=Birmingham&polygon_geojson=1&format=json
# 0.3047907999999999
# 0.22765280000000132
# grid length 28
# ready to plot 52.4796992 -1.9026911 28
# url https://nominatim.openstreetmap.org/search.php?q=Adelaide&polygon_geojson=1&format=json
# 0.047042400000009366
# 0.04323360000000065
# grid length 4
# ready to plot -34.92030445 138.59704811407516 4
# url https://nominatim.openstreetmap.org/search.php?q=Brisbaine&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Perth&polygon_geojson=1&format=json
# 0.7072464999999966
# 0.6413161999999986
# grid length 132
# ready to plot 43.4935991 -81.0164111 132
# url https://nominatim.openstreetmap.org/search.php?q=Auckland&polygon_geojson=1&format=json
# 2.006886700000024
# 1.6660816999999994
# next threshold 0.1
# grid length 203
# ready to plot -36.5412811 174.5506104914412 203
# [<folium.folium.Map at 0x1a35a0d410>,
#  <folium.folium.Map at 0x1a36e44450>,
#  <folium.folium.Map at 0x1a36be0c90>,
#  <folium.folium.Map at 0x1a36c78150>,
#  <folium.folium.Map at 0x1a35acef90>,
#  <folium.folium.Map at 0x1a36c07850>,
#  None,
#  <folium.folium.Map at 0x1a36165d50>,
#  <folium.folium.Map at 0x1a36f057d0>,
#  <folium.folium.Map at 0x1a36c784d0>,
#  <folium.folium.Map at 0x1a36de6450>,
#  <folium.folium.Map at 0x1a35b0bf10>,
#  <folium.folium.Map at 0x1a35f4a710>,
#  <folium.folium.Map at 0x1a36b0c650>,
#  <folium.folium.Map at 0x1a3632cf50>,
#  <folium.folium.Map at 0x1a35b0b890>,
#  <folium.folium.Map at 0x1a36c84790>,
#  <folium.folium.Map at 0x1a36afe550>,
#  <folium.folium.Map at 0x1a368f1fd0>,
#  <folium.folium.Map at 0x1a36d9c690>,
#  <folium.folium.Map at 0x1a36a1b810>,
#  <folium.folium.Map at 0x1a3757c210>,
#  <folium.folium.Map at 0x1a368f1dd0>,
#  <folium.folium.Map at 0x1a3741c490>,
#  <folium.folium.Map at 0x1a3757c410>,
#  <folium.folium.Map at 0x1a378f06d0>,
#  <folium.folium.Map at 0x1a375859d0>,
#  None,
#  <folium.folium.Map at 0x1a377beb10>,
#  <folium.folium.Map at 0x1a37169510>,
#  None,
#  <folium.folium.Map at 0x1a3786b590>,
#  <folium.folium.Map at 0x1a375a2250>,
#  <folium.folium.Map at 0x1a37851510>,
#  <folium.folium.Map at 0x1a37d8d2d0>,
#  <folium.folium.Map at 0x1a3786ba50>,
#  <folium.folium.Map at 0x1a381508d0>,
#  <folium.folium.Map at 0x1a38bf78d0>,
#  <folium.folium.Map at 0x1a37877c50>,
#  <folium.folium.Map at 0x1a391cff90>,
#  <folium.folium.Map at 0x1a378778d0>,
#  <folium.folium.Map at 0x1a377dc090>,
#  <folium.folium.Map at 0x1a37791d90>,
#  <folium.folium.Map at 0x1a37593490>,
#  <folium.folium.Map at 0x1a37f7a110>,
#  <folium.folium.Map at 0x1a37701110>,
#  <folium.folium.Map at 0x1a38291cd0>,
#  <folium.folium.Map at 0x1a37724450>,
#  <folium.folium.Map at 0x1a36ef5690>,
#  <folium.folium.Map at 0x1a36f14f90>,
#  <folium.folium.Map at 0x1a38a5a710>,
#  <folium.folium.Map at 0x1a36a8e810>,
#  <folium.folium.Map at 0x1a381e3b50>,
#  <folium.folium.Map at 0x1a38098d50>,
#  <folium.folium.Map at 0x1a384a2810>,
#  <folium.folium.Map at 0x1a362990d0>,
#  <folium.folium.Map at 0x1a3830a290>,
#  <folium.folium.Map at 0x1a38b2bb50>,
#  <folium.folium.Map at 0x1a381e3a10>,
#  <folium.folium.Map at 0x1a39ba2890>,
#  <folium.folium.Map at 0x1a36f14590>,
#  None,
#  <folium.folium.Map at 0x1a38336910>,
#  <folium.folium.Map at 0x1a3897d250>,
#  <folium.folium.Map at 0x1a38b2b410>,
#  <folium.folium.Map at 0x1a38bdb2d0>,
#  <folium.folium.Map at 0x1a38130290>,
#  <folium.folium.Map at 0x1a38b34250>,
#  <folium.folium.Map at 0x1a39b65e90>,
#  None,
#  <folium.folium.Map at 0x1a382cf850>,
#  <folium.folium.Map at 0x1a3866b810>,
#  <folium.folium.Map at 0x1a39bb39d0>,
#  <folium.folium.Map at 0x1a3974a690>,
#  <folium.folium.Map at 0x1a3a0ba210>,
#  <folium.folium.Map at 0x1a392e9e10>,
#  <folium.folium.Map at 0x1a3a120e90>,
#  <folium.folium.Map at 0x1a39341390>,
#  None,
#  <folium.folium.Map at 0x1a39aacc50>,
#  <folium.folium.Map at 0x1a3866ba10>,
#  <folium.folium.Map at 0x1a398d65d0>,
#  None,
#  None,
#  <folium.folium.Map at 0x1a3877af90>,
#  <folium.folium.Map at 0x1a3970d450>,
#  <folium.folium.Map at 0x1a39c5bbd0>,
#  <folium.folium.Map at 0x1a382fe890>,
#  <folium.folium.Map at 0x1a39d55910>,
#  <folium.folium.Map at 0x1a3aa90310>,
#  <folium.folium.Map at 0x1a3956d710>,
#  <folium.folium.Map at 0x1a3ae3b150>,
#  <folium.folium.Map at 0x1a3a801e90>,
#  <folium.folium.Map at 0x1a397f72d0>,
#  <folium.folium.Map at 0x1a39bc6c50>,
#  <folium.folium.Map at 0x1a382ec210>,
#  None,
#  None,
#  <folium.folium.Map at 0x1a3aa0f150>,
#  <folium.folium.Map at 0x1a3b1e39d0>,
#  <folium.folium.Map at 0x1a3a969710>,
#  <folium.folium.Map at 0x1a3a482d10>,
#  <folium.folium.Map at 0x1a3a8cd9d0>,
#  <folium.folium.Map at 0x1a3b198310>,
#  <folium.folium.Map at 0x1a3aa83190>,
#  <folium.folium.Map at 0x1a3b581910>,
#  <folium.folium.Map at 0x1a3933b190>,
#  None,
#  <folium.folium.Map at 0x1a3b629550>,
#  <folium.folium.Map at 0x1a3a96d750>,
#  <folium.folium.Map at 0x1a3b18b750>,
#  <folium.folium.Map at 0x1a3a832b90>,
#  <folium.folium.Map at 0x1a3b03ee50>,
#  <folium.folium.Map at 0x1a3b5817d0>,
#  <folium.folium.Map at 0x1a3b5c7750>,
#  <folium.folium.Map at 0x1a3a3b2dd0>,
#  <folium.folium.Map at 0x1a3b86e390>,
#  <folium.folium.Map at 0x1a3b5a6a10>,
#  None,
#  None,
#  <folium.folium.Map at 0x1a3ba36510>,
#  <folium.folium.Map at 0x1a3b56f2d0>,
#  <folium.folium.Map at 0x1a3bc32990>,
#  <folium.folium.Map at 0x1a3a3c2b90>,
#  None,
#  <folium.folium.Map at 0x1a3a8326d0>,
#  <folium.folium.Map at 0x1a3bbae150>,
#  <folium.folium.Map at 0x1a3c467d50>,
#  <folium.folium.Map at 0x1a3bba6590>,
#  <folium.folium.Map at 0x1a3c161510>,
#  <folium.folium.Map at 0x1a3b576e10>,
#  <folium.folium.Map at 0x1a3c3bb750>,
#  <folium.folium.Map at 0x1a39286f10>,
#  <folium.folium.Map at 0x1a3c8ac610>,
#  <folium.folium.Map at 0x1a3bb9f2d0>,
#  <folium.folium.Map at 0x1a3c800750>,
#  <folium.folium.Map at 0x1a3c851050>,
#  <folium.folium.Map at 0x1a3bc1ef90>,
#  <folium.folium.Map at 0x1a3ccfd110>,
#  <folium.folium.Map at 0x1a3ca55b90>,
#  <folium.folium.Map at 0x1a3aa40990>,
#  <folium.folium.Map at 0x1a3ca2c350>,
#  <folium.folium.Map at 0x1a3bfb2e50>,
#  <folium.folium.Map at 0x1a3c46cb50>,
#  <folium.folium.Map at 0x1a3d081350>,
#  <folium.folium.Map at 0x1a3bb75f50>,
#  None,
#  <folium.folium.Map at 0x1a3bfbe3d0>,
#  <folium.folium.Map at 0x1a3cced510>,
#  <folium.folium.Map at 0x1a3cdea510>,
#  <folium.folium.Map at 0x1a3cefd810>,
#  <folium.folium.Map at 0x1a3cced950>,
#  <folium.folium.Map at 0x1a3cef9f90>,
#  <folium.folium.Map at 0x1a3cefab90>,
#  <folium.folium.Map at 0x1a3c46c910>,
#  <folium.folium.Map at 0x1a3d806790>,
#  <folium.folium.Map at 0x1a3d2c0610>,
#  <folium.folium.Map at 0x1a3cf432d0>,
#  <folium.folium.Map at 0x1a3d324250>,
#  <folium.folium.Map at 0x1a3d2dfd90>,
#  None,
#  <folium.folium.Map at 0x1a3d592490>,
#  <folium.folium.Map at 0x1a3d95c890>]

# %%
missing_cities = ['Accra',
 'Alexandria',
 'Algiers',
 'Ankara',
 'Antananarivo',
 'Ashgabat',
 'Asuncion Metro',
 'Atlanta',
 'Bamako',
 'Bangui',
 'Beirut',
 'Benghazi',
 'Bergen',
 'Bishkek',
 'Bratislava',
 'Brazzaville',
 'Brisbane',
 'Cameroon',
 'Cape Town',
 'Caracas',
 'Chisinau',
 'Christchurch',
 'Colombo',
 'Cork',
 'Cotonou',
 'Delhi',
 'Denmark',
 'Douala',
 'Dushanbe',
 'Gaborone',
 'Gaza',
 'Goteborg',
 'Guatemala City',
 'Guayaquil',
 'Israel',
 'Jeddah',
 'Kaunas',
 'Khartoum',
 'Kiev',
 'Kigali',
 'Kinshasa',
 'Kumasi',
 'Kuwait City',
 'La Paz',
 'Lahore',
 'Lefkosia',
 'Libreville',
 'Limassol',
 'Ljubljana',
 'Lome',
 'Male',
 'Managua',
 'Manama',
 'Maseru',
 'Mecca',
 'Medina',
 'Miami',
 'Monrovia',
 'NDjamena',
 'Nicosia',
 'Nouakchott',
 'Pafos',
 'Pointe-Noire',
 'Port-Louis',
 'Port-au-Prince',
 'Prishtine',
 'San Jose',
 'San Miguelito',
 'San Pedro Sula',
 'San Salvador',
 'Sanaa',
 'Sarajevo',
 'Skopje',
 'South Sudan',
 'Thessaloniki',
 'Tirana',
 'Tripoli',
 'Tunis',
 'Ulaanbaatar',
 'Vientiane/Vianchan',
 'Vilnius',
 'Wellington',
 'Windhoek']

# %%
[generate_and_save_city_grid(i, 0.05) for i in missing_cities]
# Out:
# url https://nominatim.openstreetmap.org/search.php?q=Accra&polygon_geojson=1&format=json
# 0.00013700000000005375
# 8.640000000070813e-05
# grid length 1
# ready to plot 51.4503833 -0.9079996000000001 1
# url https://nominatim.openstreetmap.org/search.php?q=Alexandria&polygon_geojson=1&format=json
# 0.10731979999999908
# 0.06052629999999937
# grid length 6
# ready to plot 38.8147596 -77.09024765272724 6
# url https://nominatim.openstreetmap.org/search.php?q=Algiers&polygon_geojson=1&format=json
# 20.666245
# 18.3280585
# next threshold 0.2
# grid length 5608
# ready to plot 28.0000272 2.9999825 5608
# url https://nominatim.openstreetmap.org/search.php?q=Ankara&polygon_geojson=1&format=json
# 3.039952099999997
# 2.0964607000000015
# next threshold 0.1
# grid length 340
# ready to plot 39.7160439 32.7059948 340
# url https://nominatim.openstreetmap.org/search.php?q=Antananarivo&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Ashgabat&polygon_geojson=1&format=json
# 0.4863665000000026
# 0.33477229999999736
# grid length 63
# ready to plot 37.9396678 58.3874263 63
# url https://nominatim.openstreetmap.org/search.php?q=Asuncion+Metro&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Atlanta&polygon_geojson=1&format=json
# 0.2615080000000063
# 0.23901500000000198
# grid length 29
# ready to plot 33.7490987 -84.3901849 29
# url https://nominatim.openstreetmap.org/search.php?q=Bamako&polygon_geojson=1&format=json
# 0.16913999999999962
# 0.1995900000000006
# grid length 15
# ready to plot 12.60503275 -7.986513673439357 15
# url https://nominatim.openstreetmap.org/search.php?q=Bangui&polygon_geojson=1&format=json
# 0.12020240000000015
# 0.1093099000000004
# grid length 7
# ready to plot 5.0726761 18.1717789 7
# url https://nominatim.openstreetmap.org/search.php?q=Beirut&polygon_geojson=1&format=json
# 0.07580420000000032
# 0.05378189999999705
# grid length 4
# ready to plot 33.8959203 35.47843 4
# url https://nominatim.openstreetmap.org/search.php?q=Benghazi&polygon_geojson=1&format=json
# 1.5999240000000015
# 1.7275804999999949
# grid length 712
# ready to plot 31.7835199 20.6215663 712
# url https://nominatim.openstreetmap.org/search.php?q=Bergen&polygon_geojson=1&format=json
# 0.5422130000000003
# 0.3600020000000015
# grid length 56
# ready to plot 60.3943055 5.3259192 56
# url https://nominatim.openstreetmap.org/search.php?q=Bishkek&polygon_geojson=1&format=json
# 0.22414999999999452
# 0.18452560000000062
# grid length 18
# ready to plot 42.8799039 74.58589060950959 18
# url https://nominatim.openstreetmap.org/search.php?q=Bratislava&polygon_geojson=1&format=json
# 0.27412619999999777
# 0.23665869999999956
# grid length 25
# ready to plot 48.1516988 17.1093063 25
# url https://nominatim.openstreetmap.org/search.php?q=Brazzaville&polygon_geojson=1&format=json
# 1.0060758000000014
# 1.0839308
# grid length 242
# ready to plot -3.9702077 15.4664017803497 242
# url https://nominatim.openstreetmap.org/search.php?q=Brisbane&polygon_geojson=1&format=json
# 0.17645320000001163
# 0.036994400000004646
# grid length 8
# ready to plot 37.687165 -122.4027942 8
# url https://nominatim.openstreetmap.org/search.php?q=Cameroon&polygon_geojson=1&format=json
# 7.806379700000001
# 11.434351
# next threshold 0.2
# grid length 1102
# ready to plot 4.6125522 13.1535811 1102
# url https://nominatim.openstreetmap.org/search.php?q=Cape+Town&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Caracas&polygon_geojson=1&format=json
# 0.031516300000006936
# 0.025365900000000607
# grid length 2
# ready to plot 4.931658649999999 -75.74872878365295 2
# url https://nominatim.openstreetmap.org/search.php?q=Chisinau&polygon_geojson=1&format=json
# 0.22825510000000193
# 0.1592798000000002
# grid length 18
# ready to plot 47.0244707 28.8322534 18
# url https://nominatim.openstreetmap.org/search.php?q=Christchurch&polygon_geojson=1&format=json
# 0.42860189999998966
# 0.24011480000000063
# grid length 39
# ready to plot -43.530955 172.6366455 39
# url https://nominatim.openstreetmap.org/search.php?q=Colombo&polygon_geojson=1&format=json
# 0.06954469999999446
# 0.11872410000000055
# grid length 5
# ready to plot 6.9349969 79.8538463 5
# url https://nominatim.openstreetmap.org/search.php?q=Cork&polygon_geojson=1&format=json
# 2.4614240999999994
# 0.9989194999999995
# next threshold 0.1
# grid length 146
# ready to plot 51.91750415 -8.585992213774254 146
# url https://nominatim.openstreetmap.org/search.php?q=Cotonou&polygon_geojson=1&format=json
# 0.17296639999999996
# 0.2584749999999998
# grid length 24
# ready to plot 6.2525776 2.4295328350075436 24
# url https://nominatim.openstreetmap.org/search.php?q=Delhi&polygon_geojson=1&format=json
# 0.5077659000000097
# 0.47881789999999924
# grid length 78
# ready to plot 28.6273928 77.1716954 78
# url https://nominatim.openstreetmap.org/search.php?q=Denmark&polygon_geojson=1&format=json
# 7.837738600000001
# 3.5007630000000063
# next threshold 0.2
# grid length 380
# ready to plot 55.670249 10.3333283 380
# url https://nominatim.openstreetmap.org/search.php?q=Douala&polygon_geojson=1&format=json
# 0.528278199999999
# 0.48180069999999997
# grid length 64
# ready to plot 4.0537386 9.664436579233602 64
# url https://nominatim.openstreetmap.org/search.php?q=Dushanbe&polygon_geojson=1&format=json
# 0.30657200000000273
# 0.1894608000000062
# grid length 25
# ready to plot 38.5762709 68.7863573 25
# url https://nominatim.openstreetmap.org/search.php?q=Gaborone&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Gaza&polygon_geojson=1&format=json
# 0.3509544000000062
# 0.3769953000000008
# grid length 29
# ready to plot 31.4331663 34.3779285 29
# url https://nominatim.openstreetmap.org/search.php?q=Goteborg&polygon_geojson=1&format=json
# 0.3779313000000002
# 0.348419100000001
# grid length 40
# ready to plot 57.7072326 11.9670171 40
# url https://nominatim.openstreetmap.org/search.php?q=Guatemala+City&polygon_geojson=1&format=json
# 0.2016992000000073
# 0.17257749999999916
# grid length 19
# ready to plot 14.6222328 -90.5185188 19
# url https://nominatim.openstreetmap.org/search.php?q=Guayaquil&polygon_geojson=1&format=json
# 0.10276880000000688
# 0.23466169999999975
# grid length 12
# ready to plot -2.1899066 -79.887726 12
# url https://nominatim.openstreetmap.org/search.php?q=Israel&polygon_geojson=1&format=json
# 1.627524000000001
# 3.8822520999999988
# next threshold 0.1
# grid length 319
# ready to plot 31.5313113 34.8667654 319
# url https://nominatim.openstreetmap.org/search.php?q=Jeddah&polygon_geojson=1&format=json
# 0.006762700000003008
# 0.007163199999997261
# grid length 1
# ready to plot 26.291266200000003 50.09636271029822 1
# url https://nominatim.openstreetmap.org/search.php?q=Kaunas&polygon_geojson=1&format=json
# 0.3468541999999992
# 0.13900109999999444
# grid length 22
# ready to plot 54.8982139 23.9044817 22
# url https://nominatim.openstreetmap.org/search.php?q=Khartoum&polygon_geojson=1&format=json
# 0.3917028999999985
# 0.4767770999999996
# grid length 61
# ready to plot 15.593325 32.53565 61
# url https://nominatim.openstreetmap.org/search.php?q=Kiev&polygon_geojson=1&format=json
# 0.5912638000000001
# 0.3775908000000001
# grid length 66
# ready to plot 50.402086499999996 30.614680312884797 66
# url https://nominatim.openstreetmap.org/search.php?q=Kigali&polygon_geojson=1&format=json
# 0.30034450000000135
# 0.3006892000000001
# grid length 41
# ready to plot -1.92965425 30.134756082021365 41
# url https://nominatim.openstreetmap.org/search.php?q=Kinshasa&polygon_geojson=1&format=json
# 0.018177999999998917
# 0.02351290000000006
# grid length 1
# ready to plot -4.3218539499999995 15.311837908367066 1
# url https://nominatim.openstreetmap.org/search.php?q=Kumasi&polygon_geojson=1&format=json
# 0.0003641999999999257
# 0.00035929999999950724
# grid length 1
# ready to plot 49.192787100000004 -2.123797886441899 1
# url https://nominatim.openstreetmap.org/search.php?q=Kuwait+City&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=La+Paz&polygon_geojson=1&format=json
# 0.6221380000000067
# 0.8336728000000022
# grid length 104
# ready to plot -16.4955455 -68.1336229 104
# url https://nominatim.openstreetmap.org/search.php?q=Lahore&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Lefkosia&polygon_geojson=1&format=json
# 0.07042390000000154
# 0.05836610000000064
# grid length 5
# ready to plot 35.18089155 33.37325855497367 5
# url https://nominatim.openstreetmap.org/search.php?q=Libreville&polygon_geojson=1&format=json
# 0.8701606999999996
# 0.5987337
# grid length 156
# ready to plot 0.450202 9.516160556041065 156
# url https://nominatim.openstreetmap.org/search.php?q=Limassol&polygon_geojson=1&format=json
# 0.6413322000000008
# 0.3307889000000017
# grid length 73
# ready to plot 34.79489125 32.985589384507975 73
# url https://nominatim.openstreetmap.org/search.php?q=Ljubljana&polygon_geojson=1&format=json
# 0.34671499999999966
# 0.17193309999999684
# grid length 25
# ready to plot 46.0499803 14.5068602 25
# url https://nominatim.openstreetmap.org/search.php?q=Lome&polygon_geojson=1&format=json
# 0.13029539999999984
# 0.09174620000000022
# grid length 10
# ready to plot 6.15803455 1.2516823732466333 10
# url https://nominatim.openstreetmap.org/search.php?q=Male&polygon_geojson=1&format=json
# 16.5076663
# 14.853272999999998
# next threshold 0.2
# grid length 2873
# ready to plot 16.3700359 -2.2900239 2873
# url https://nominatim.openstreetmap.org/search.php?q=Managua&polygon_geojson=1&format=json
# 0.2660589999999985
# 0.20309059999999945
# grid length 22
# ready to plot 12.12278585 -86.23007064556546 22
# url https://nominatim.openstreetmap.org/search.php?q=Manama&polygon_geojson=1&format=json
# 0.0006812999999965541
# 0.0005975999999989767
# grid length 1
# ready to plot 25.1299699 56.328283800813026 1
# url https://nominatim.openstreetmap.org/search.php?q=Maseru&polygon_geojson=1&format=json
# 1.0200791000000002
# 0.6816268000000001
# grid length 201
# ready to plot -29.5816942 27.8243208 201
# url https://nominatim.openstreetmap.org/search.php?q=Mecca&polygon_geojson=1&format=json
# 0.14623050000000148
# 0.0939148000000003
# grid length 7
# ready to plot 33.5511969 -116.06970822122544 7
# url https://nominatim.openstreetmap.org/search.php?q=Medina&polygon_geojson=1&format=json
# 0.6092311999999964
# 0.6020429000000007
# grid length 156
# ready to plot 29.2836281 -99.1126826 156
# url https://nominatim.openstreetmap.org/search.php?q=Miami&polygon_geojson=1&format=json
# 0.18060300000000495
# 0.14673099999999906
# grid length 13
# ready to plot 25.7742658 -80.1936589 13
# url https://nominatim.openstreetmap.org/search.php?q=Monrovia&polygon_geojson=1&format=json
# 0.08051000000000386
# 0.09127900000000011
# grid length 5
# ready to plot 34.1483499 -118.0014517 5
# url https://nominatim.openstreetmap.org/search.php?q=NDjamena&polygon_geojson=1&format=json
# 0.29727820000000094
# 0.19952269999999928
# grid length 23
# ready to plot 12.152619399999999 15.02002275287964 23
# url https://nominatim.openstreetmap.org/search.php?q=Nicosia&polygon_geojson=1&format=json
# 0.07042390000000154
# 0.05836610000000064
# grid length 5
# ready to plot 35.18089155 33.37325855497367 5
# url https://nominatim.openstreetmap.org/search.php?q=Nouakchott&polygon_geojson=1&format=json
# 0.26962899999999834
# 0.5066123999999981
# grid length 67
# ready to plot 18.13799105 -15.904955749779141 67
# url https://nominatim.openstreetmap.org/search.php?q=Pafos&polygon_geojson=1&format=json
# 0.06611420000000123
# 0.05880700000000161
# grid length 6
# ready to plot 34.7743988 32.4231586 6
# url https://nominatim.openstreetmap.org/search.php?q=Pointe-Noire&polygon_geojson=1&format=json
# 0.669748199999999
# 0.7985515999999997
# grid length 166
# ready to plot -4.74859545 11.901781009574806 166
# url https://nominatim.openstreetmap.org/search.php?q=Port-Louis&polygon_geojson=1&format=json
# 0.027196200000000115
# 0.013710500000001957
# grid length 2
# ready to plot 47.7107 -3.34807 2
# url https://nominatim.openstreetmap.org/search.php?q=Port-au-Prince&polygon_geojson=1&format=json
# 0.41083650000000205
# 0.29083590000000115
# grid length 44
# ready to plot 18.48536835 -72.37545392251451 44
# url https://nominatim.openstreetmap.org/search.php?q=Prishtine&polygon_geojson=1&format=json
# 0.10699739999999736
# 0.06787039999999678
# grid length 5
# ready to plot 42.6638771 21.1640849 5
# url https://nominatim.openstreetmap.org/search.php?q=San+Jose&polygon_geojson=1&format=json
# 0.4565190000000001
# 0.34471450000000203
# grid length 44
# ready to plot 37.3361905 -121.8905833 44
# url https://nominatim.openstreetmap.org/search.php?q=San+Miguelito&polygon_geojson=1&format=json
# 0.11614129999999534
# 0.06652650000000015
# grid length 6
# ready to plot 9.0552226 -79.4930756 6
# url https://nominatim.openstreetmap.org/search.php?q=San+Pedro+Sula&polygon_geojson=1&format=json
# 0.1373812000000072
# 0.15156049999999865
# grid length 12
# ready to plot 15.5062156 -88.0248937 12
# url https://nominatim.openstreetmap.org/search.php?q=San+Salvador&polygon_geojson=1&format=json
# 0.11391410000000235
# 0.11329859999999847
# grid length 8
# ready to plot 13.68923495 -89.20854103862447 8
# url https://nominatim.openstreetmap.org/search.php?q=Sanaa&polygon_geojson=1&format=json
# 0.1735327999999967
# 0.23821200000000076
# grid length 20
# ready to plot 15.3538569 44.2058841 20
# url https://nominatim.openstreetmap.org/search.php?q=Sarajevo&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Skopje&polygon_geojson=1&format=json
# 0.22230149999999682
# 0.1091466999999966
# grid length 11
# ready to plot 41.9960924 21.4316495 11
# url https://nominatim.openstreetmap.org/search.php?q=South+Sudan&polygon_geojson=1&format=json
# 12.501218999999999
# 8.747409000000001
# next threshold 0.2
# grid length 1476
# ready to plot 7.8699431 29.6667897 1476
# url https://nominatim.openstreetmap.org/search.php?q=Thessaloniki&polygon_geojson=1&format=json
# 0.00023850000000003035
# 0.00017169999999566699
# grid length 1
# ready to plot 53.652034 9.77614625 1
# url https://nominatim.openstreetmap.org/search.php?q=Tirana&polygon_geojson=1&format=json
# 0.12170370000000119
# 0.06988849999999758
# grid length 9
# ready to plot 41.3268733 19.8187913 9
# url https://nominatim.openstreetmap.org/search.php?q=Tripoli&polygon_geojson=1&format=json
# 0.5325507000000016
# 0.2958889999999954
# grid length 52
# ready to plot 32.896672 13.1777923 52
# url https://nominatim.openstreetmap.org/search.php?q=Tunis&polygon_geojson=1&format=json
# 4.358132599999999
# 7.532144199999998
# next threshold 0.2
# grid length 532
# ready to plot 33.8439408 9.400138 532
# url https://nominatim.openstreetmap.org/search.php?q=Ulaanbaatar&polygon_geojson=1&format=json
# 1.2217810000000071
# 0.6218689999999967
# grid length 237
# ready to plot 47.9184676 106.9177016 237
# url https://nominatim.openstreetmap.org/search.php?q=Vientiane%2FVianchan&polygon_geojson=1&format=json
# Unable to Find City
# url https://nominatim.openstreetmap.org/search.php?q=Vilnius&polygon_geojson=1&format=json
# 0.45704569999999833
# 0.26298260000000084
# grid length 43
# ready to plot 54.6870458 25.2829111 43
# url https://nominatim.openstreetmap.org/search.php?q=Wellington&polygon_geojson=1&format=json
# 0.02165300000000059
# 0.02237999999999829
# grid length 2
# ready to plot 34.856166 -100.2137263 2
# url https://nominatim.openstreetmap.org/search.php?q=Windhoek&polygon_geojson=1&format=json
# 0.14375240000000034
# 0.1678841999999996
# grid length 12
# ready to plot -22.5743922 17.0790688 12
# [<folium.folium.Map at 0x1a248e1810>,
#  <folium.folium.Map at 0x1a25db4390>,
#  <folium.folium.Map at 0x1a26c98990>,
#  <folium.folium.Map at 0x1a26b67950>,
#  None,
#  <folium.folium.Map at 0x1a248ec590>,
#  None,
#  <folium.folium.Map at 0x1a25f25e90>,
#  <folium.folium.Map at 0x1a248dc750>,
#  <folium.folium.Map at 0x1a248ff990>,
#  <folium.folium.Map at 0x1a27ca0ad0>,
#  <folium.folium.Map at 0x1a26464310>,
#  <folium.folium.Map at 0x1a25d54d10>,
#  <folium.folium.Map at 0x1a264504d0>,
#  <folium.folium.Map at 0x1a26439350>,
#  <folium.folium.Map at 0x1a2625c110>,
#  <folium.folium.Map at 0x1a26450490>,
#  <folium.folium.Map at 0x1a267663d0>,
#  None,
#  <folium.folium.Map at 0x1a265c8610>,
#  <folium.folium.Map at 0x1a26337d90>,
#  <folium.folium.Map at 0x1a2889a790>,
#  <folium.folium.Map at 0x1a261dc650>,
#  <folium.folium.Map at 0x1a291d6c10>,
#  <folium.folium.Map at 0x1a26c71f10>,
#  <folium.folium.Map at 0x1a25da2e10>,
#  <folium.folium.Map at 0x1a28b9d8d0>,
#  <folium.folium.Map at 0x1a27b40c50>,
#  <folium.folium.Map at 0x1a286a6c90>,
#  None,
#  <folium.folium.Map at 0x1a25da0a10>,
#  <folium.folium.Map at 0x1a28043390>,
#  <folium.folium.Map at 0x1a260c7590>,
#  <folium.folium.Map at 0x1a288a3750>,
#  <folium.folium.Map at 0x1a2925f4d0>,
#  <folium.folium.Map at 0x1a26736f50>,
#  <folium.folium.Map at 0x1a288a4550>,
#  <folium.folium.Map at 0x1a2869df10>,
#  <folium.folium.Map at 0x1a2973ee90>,
#  <folium.folium.Map at 0x1a27dd1d10>,
#  <folium.folium.Map at 0x1a286a2210>,
#  <folium.folium.Map at 0x1a286a0150>,
#  None,
#  <folium.folium.Map at 0x1a27cda150>,
#  None,
#  <folium.folium.Map at 0x1a286a2dd0>,
#  <folium.folium.Map at 0x1a26525310>,
#  <folium.folium.Map at 0x1a286a0d90>,
#  <folium.folium.Map at 0x1a26ad8b50>,
#  <folium.folium.Map at 0x1a2972a6d0>,
#  <folium.folium.Map at 0x1a2a254810>,
#  <folium.folium.Map at 0x1a2a225450>,
#  <folium.folium.Map at 0x1a2972a490>,
#  <folium.folium.Map at 0x1a2691ddd0>,
#  <folium.folium.Map at 0x1a2a225850>,
#  <folium.folium.Map at 0x1a2684d890>,
#  <folium.folium.Map at 0x1a267a8250>,
#  <folium.folium.Map at 0x1a2ae8ee90>,
#  <folium.folium.Map at 0x1a267a8e10>,
#  <folium.folium.Map at 0x1a2aeb7c50>,
#  <folium.folium.Map at 0x1a2686cf90>,
#  <folium.folium.Map at 0x1a289151d0>,
#  <folium.folium.Map at 0x1a290003d0>,
#  <folium.folium.Map at 0x11732db10>,
#  <folium.folium.Map at 0x11732d0d0>,
#  <folium.folium.Map at 0x1a28e68ed0>,
#  <folium.folium.Map at 0x1a26ab2a90>,
#  <folium.folium.Map at 0x1a28a5a990>,
#  <folium.folium.Map at 0x1170f2d10>,
#  <folium.folium.Map at 0x1a27f9e210>,
#  <folium.folium.Map at 0x1a2917e690>,
#  None,
#  <folium.folium.Map at 0x1a288d8910>,
#  <folium.folium.Map at 0x1a2b242350>,
#  <folium.folium.Map at 0x1a27f9ecd0>,
#  <folium.folium.Map at 0x1a267aff90>,
#  <folium.folium.Map at 0x1a29e637d0>,
#  <folium.folium.Map at 0x1a2a1e30d0>,
#  <folium.folium.Map at 0x1a2b256990>,
#  None,
#  <folium.folium.Map at 0x1a2b0c1fd0>,
#  <folium.folium.Map at 0x1a2bb87390>,
#  <folium.folium.Map at 0x1a2b2820d0>]

# %%
missing_cities = [
 'Algiers',
 'Cameroon',
 'South Sudan']

# %%
[generate_and_save_city_grid(i, 0.05) for i in missing_cities]
# Out:
# url https://nominatim.openstreetmap.org/search.php?q=Algiers&polygon_geojson=1&format=json
# 20.666245
# 18.3280585
# next threshold 0.5
# next threshold 2.0
# grid length 75
# ready to plot 28.0000272 2.9999825 75
# url https://nominatim.openstreetmap.org/search.php?q=Cameroon&polygon_geojson=1&format=json
# 7.806379700000001
# 11.434351
# next threshold 0.5
# next threshold 2.0
# grid length 20
# ready to plot 4.6125522 13.1535811 20
# url https://nominatim.openstreetmap.org/search.php?q=South+Sudan&polygon_geojson=1&format=json
# 12.501218999999999
# 8.747409000000001
# next threshold 0.5
# next threshold 2.0
# grid length 26
# ready to plot 7.8699431 29.6667897 26
# [<folium.folium.Map at 0x1a25fa8250>,
#  <folium.folium.Map at 0x1a24846a10>,
#  <folium.folium.Map at 0x1a26141690>]
