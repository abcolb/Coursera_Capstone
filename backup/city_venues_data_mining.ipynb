# %% [markdown]
# # World Financial Centers' Venues Data Mining

# %% [markdown]
# - Combines and deduplicates geospatial neighborhood data
# - Requests Foursquare nearby venues and venue categories to build profile of each neighborhood
#
#
# - Required inputs
#  - cities_ratings.csv
# - Outputs
#  - 'world_neighborhood_coords.csv'

# %% [markdown]
# ## Table of Contents
#
# 1. [Compile Global Neighborhood Coordinates](#clean)
#
# 2. [Fetch Foursquare Categories](#foursquare-categories)
#
# 3. [Fetch Foursquare Venues](#foursquare)
#
# 4. [Prepare model input features](#model-input)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from foursquare import fetch_city_venues, fetch_venue_categories, venue_frequency, rank_venues_by_frequency
from geocoder import enrich_neighborhoods_with_geocoder, map_neighborhoods, map_clusters

# %% [markdown]
# ## Compile global neighborhood coordinates
# <a id="clean"/>

# %%
ratings = pd.read_csv('data/cities_ratings.csv', index_col=0)
ratings.head()
# Out:
#              Centre Rating
# Rank
# 1     New York City    790
# 2            London    773
# 3         Hong Kong    771
# 4         Singapore    762
# 5          Shanghai    761

# %% [markdown]
# ## Fetch venue categories from Foursquare
# <a id='foursquare-categories' />

# %%
categories = fetch_venue_categories()
categories

# %%
c = pd.DataFrame(categories)
c

# %%
# c.to_csv('data/foursquare_venues.csv')
c = pd.read_csv('data/foursquare_venues.csv', index_col=0)

c.set_index('name', drop=True, inplace=True)
c

# %%
categories = list(c.category.value_counts().index)
categories

# %% [markdown]
# ## Fetch neighborhood venues from Foursquare
# <a id='foursquare' />

# %%
world_venues = fetch_city_venues(cities=ratings[0:2].Centre) #ratings[0:2].Centre
world_venues
# Out:
# https://api.foursquare.com/v2/venues/explore?&client_id=5YWYDD1OYF3I3QYJMUFJX3O1UDV5MU4NCBI30FYK4YHMGWQ4&client_secret=LFUHV1IDE4KESRNAONHO1YX42CCC5GICZ112WKKL3HHJ2PGU&v=20180605&near=New York City&intent=browse
# https://api.foursquare.com/v2/venues/explore?&client_id=5YWYDD1OYF3I3QYJMUFJX3O1UDV5MU4NCBI30FYK4YHMGWQ4&client_secret=LFUHV1IDE4KESRNAONHO1YX42CCC5GICZ112WKKL3HHJ2PGU&v=20180605&near=London&intent=browse
#              City                                              Venue  \
# 0   New York City                                       Central Park
# 1   New York City                               Brooklyn Bridge Park
# 2   New York City                            Gantry Plaza State Park
# 3   New York City                                   Minskoff Theatre
# 4   New York City                 Hudson River Greenway Running Path
# 5   New York City                                Conservatory Garden
# 6   New York City                                        Bryant Park
# 7   New York City                                  Hudson River Park
# 8   New York City  The Metropolitan Museum of Art (Metropolitan M...
# 9   New York City                                    Los Tacos No. 1
# 10  New York City                              Astor Wines & Spirits
# 11  New York City                                         Metrograph
# 12  New York City                                 Aire Ancient Baths
# 13  New York City                            St. Patrick's Cathedral
# 14  New York City                                          High Line
# 15  New York City                                     Riverside Park
# 16  New York City                             Washington Square Park
# 17  New York City                                   Elf Cosmetics HQ
# 18  New York City             Lincoln Center for the Performing Arts
# 19  New York City                              David Zwirner Gallery
# 20  New York City                           Equinox West 50th Street
# 21  New York City                                            Peloton
# 22  New York City                                  Bethesda Fountain
# 23  New York City                      Brooklyn Bridge Park - Pier 6
# 24  New York City                      Brooklyn Bridge Park - Pier 5
# 25  New York City                              David H. Koch Theater
# 26  New York City                                 The Public Theater
# 27  New York City        The Metropolitan Opera (Metropolitan Opera)
# 28  New York City                                   Strand Bookstore
# 29  New York City                                    Brooklyn Bridge
# 30         London                                    Hampstead Heath
# 31         London                                          Hyde Park
# 32         London                                      Regent's Park
# 33         London                                     Greenwich Park
# 34         London                                      Primrose Hill
# 35         London                     Princess of Wales Conservatory
# 36         London                                    M&S Simply Food
# 37         London                                 Kensington Gardens
# 38         London                                    St James's Park
# 39         London                    Regent's Canal (Kingsland Road)
# 40         London                                      Victoria Park
# 41         London  Royal Botanic Gardens (Royal Botanic Gardens, ...
# 42         London                                  Royal Albert Hall
# 43         London                                     Borough Market
# 44         London                        The Pergola and Hill Garden
# 45         London                                       Holland Park
# 46         London                                   The Chesham Arms
# 47         London  The Sir John Ritblat Gallery: Treasures of the...
# 48         London            The London Edition (The London EDITION)
# 49         London                           Petersham Nurseries Cafe
# 50         London                                      Richmond Park
# 51         London                                     Battersea Park
# 52         London                          Spa at Four Seasons Hotel
# 53         London                                      Clissold Park
# 54         London                                         Palm House
# 55         London                                        Scarfes Bar
# 56         London                                        Daunt Books
# 57         London                               Mount Street Gardens
# 58         London                                     Lyceum Theatre
# 59         London                                      The Ned Hotel
#
#              Venue Category  Venue Latitude  Venue Longitude
# 0                      Park       40.784083       -73.964853
# 1                      Park       40.702282       -73.996456
# 2   State / Provincial Park       40.746558       -73.958051
# 3                   Theater       40.757389       -73.985537
# 4                     Trail       40.732552       -74.010580
# 5                    Garden       40.793531       -73.952032
# 6                      Park       40.753621       -73.983265
# 7                      Park       40.733869       -74.010454
# 8                Art Museum       40.779729       -73.963416
# 9                Taco Place       40.757237       -73.987454
# 10                Wine Shop       40.727984       -73.993047
# 11      Indie Movie Theater       40.714999       -73.991035
# 12                      Spa       40.718141       -74.004941
# 13                   Church       40.758627       -73.976398
# 14                     Park       40.746825       -74.005507
# 15                     Park       40.806809       -73.968651
# 16                     Park       40.730816       -73.997458
# 17           Cosmetics Shop       40.729881       -73.992355
# 18    Performing Arts Venue       40.772282       -73.982948
# 19              Art Gallery       40.746635       -74.007329
# 20                      Gym       40.761912       -73.984268
# 21                Bike Shop       40.743469       -73.994205
# 22                 Fountain       40.774294       -73.970840
# 23                     Pier       40.693289       -74.002780
# 24                     Pier       40.694918       -74.001686
# 25                  Theater       40.772292       -73.983262
# 26                  Theater       40.729169       -73.992070
# 27              Opera House       40.772742       -73.984401
# 28                Bookstore       40.733140       -73.990912
# 29                   Bridge       40.705967       -73.996707
# 30                     Park       51.564436        -0.167363
# 31                     Park       51.507781        -0.162392
# 32                     Park       51.530479        -0.153766
# 33                     Park       51.477521         0.000858
# 34                     Park       51.539262        -0.161941
# 35         Botanical Garden       51.481540        -0.290459
# 36            Grocery Store       51.505517        -0.098047
# 37                     Park       51.506766        -0.180373
# 38                     Park       51.503253        -0.132995
# 39                    Canal       51.536966        -0.081375
# 40                     Park       51.538499        -0.035290
# 41         Botanical Garden       51.477748        -0.296631
# 42             Concert Hall       51.501122        -0.177417
# 43           Farmers Market       51.505495        -0.090518
# 44                   Garden       51.565426        -0.183506
# 45                     Park       51.503148        -0.204153
# 46                      Pub       51.547727        -0.050131
# 47                   Museum       51.529666        -0.127541
# 48                    Hotel       51.516762        -0.136049
# 49                     Café       51.447032        -0.302446
# 50                     Park       51.438905        -0.274728
# 51                     Park       51.479512        -0.156984
# 52                      Spa       51.504412        -0.150121
# 53                     Park       51.561438        -0.088457
# 54         Botanical Garden       51.479016        -0.292729
# 55                Hotel Bar       51.517813        -0.118184
# 56                Bookstore       51.520433        -0.151824
# 57                     Park       51.509143        -0.150203
# 58                  Theater       51.511598        -0.119785
# 59                    Hotel       51.513755        -0.090067

# %%
world_venues[0:20]

# %%
world_venues[49:70]

# %%
world_venues.to_csv('data/nyc_london.csv')

# %%
world_venues_1 = fetch_city_venues(cities=ratings[2:50].Centre) #ratings[0:2].Centre
world_venues_1

# %%
world_venues_1.to_csv('data/hongkong_singapore.csv')

# %%
world_venues_1[world_venues_1.duplicated()==True]

# %%
world_venues_1[0:5]

# %%
world_venues_1[100:105]

# %%
world_venues['Venue Category'].value_counts()

# %%
world_venues.City.value_counts()

# %%
world_venues.to_csv('data/world_city_venues.csv')

# world_venues = pd.read_csv('data/world_neighborhood_venues.csv', index_col=0)
# world_venues

# %% [markdown]
# ### Label Venues data with categories

# %%
s = c['category']

# %%
world_venues['Category'] = world_venues['Venue Category'].apply(lambda x: s.get(x) if s.get(x) else None)
world_venues

# %%
ax = world_venues['Category'].value_counts().plot(kind='barh')
ax.invert_yaxis()
plt.title('Total Foursquare Venue Categories Collected')
plt.show()

# %% [markdown]
# Since the bottom four categories each account for less than 1% of data points, and model features space is limited, we should drop them.

# %% [markdown]
# ### Filter out neighborhoods with venues category accounts for < 1% of venues

# %%
len(world_venues)/100

# %%
above_venue_category_threshold = world_venues.groupby('Category').count() >= len(world_venues)/100
above_venue_category_threshold

# %%
filtered_venues = world_venues[world_venues['Category'].isin(above_venue_category_threshold[above_venue_category_threshold['Venue'] == True].index)]
filtered_venues.reset_index(drop=True, inplace=True)
filtered_venues

# %% [markdown]
# ### Filter out neighborhoods with Foursquare venues count < 10

# %%
above_venue_count_threshold = world_venues[['Neighborhood', 'City', 'Venue']].groupby(['Neighborhood', 'City']).count() >= 10
above_venue_count_threshold

# %%
world_venues['Address'] = list(zip(world_venues['Neighborhood'], world_venues['City']))
filtered_venues = world_venues[world_venues['Address'].isin(above_threshold[above_threshold['Venue'] == True].index)]
filtered_venues.reset_index(drop=True, inplace=True)

# %%
filtered_venues

# %%
filtered_venues.to_csv('data/world_neighborhood_venues.csv')

# %%
len(filtered_venues)

# %%
ax = filtered_venues['Venue'].value_counts()[0:15].plot(kind='barh')
ax.invert_yaxis()
plt.title('Top 15 Foursquare Venues Collected (n=13,171)')
plt.show()

# %%
ax = filtered_venues['Venue Category'].value_counts()[0:15].plot(kind='barh')
ax.invert_yaxis()
plt.title('Top 15 Foursquare Venue Types Collected (n=13,171)')
plt.show()

# %%
filtered_venues['Category'].value_counts()

# %%
venues_by_neighborhood = filtered_venues.pivot_table(index=['Neighborhood', 'City'], columns='Category', values='Venue', aggfunc='count', fill_value=0)
venues_by_neighborhood

# %% [markdown]
# ### Convert neighborhood venue type counts to frequencies

# %%
neighborhood_venue_frequency = venues_by_neighborhood.div(venues_by_neighborhood.sum(axis=1), axis=0)
neighborhood_venue_frequency

# %%
neighborhood_venue_frequency.to_csv('data/world_neighborhood_venues_frequency.csv')
